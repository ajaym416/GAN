# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaym416/GAN/blob/main/variational_AutoEncoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import tensorflow as tf
# tf.compat.v1.enable_eager_execution()

# %%
##utils-> callbacks
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
import numpy as np
import matplotlib.pyplot as plt
import os

#### CALLBACKS
class CustomCallback(Callback):
    
    def __init__(self, run_folder, print_every_n_batches, initial_epoch, vae):
        self.epoch = initial_epoch
        self.run_folder = run_folder
        self.print_every_n_batches = print_every_n_batches
        self.vae = vae

    def on_train_batch_end(self, batch, logs={}):  
        if batch % self.print_every_n_batches == 0:
            z_new = np.random.normal(size = (1,self.vae.z_dim))
            reconst = self.vae.decoder.predict(np.array(z_new))[0].squeeze()

            filepath = os.path.join(self.run_folder, 'images', 'img_' + str(self.epoch).zfill(3) + '_' + str(batch) + '.jpg')
            if len(reconst.shape) == 2:
                plt.imsave(filepath, reconst, cmap='gray_r')
            else:
                plt.imsave(filepath, reconst)

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch += 1



def step_decay_schedule(initial_lr, decay_factor=0.5, step_size=1):
    '''
    Wrapper function to create a LearningRateScheduler with step decay schedule.
    '''
    def schedule(epoch):
        new_lr = initial_lr * (decay_factor ** np.floor(epoch/step_size))
        
        return new_lr

    return LearningRateScheduler(schedule)

# %%
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Lambda, Activation, BatchNormalization, LeakyReLU, Dropout, Layer
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint 
from tensorflow.keras.utils import plot_model

import tensorflow as tf


import numpy as np
import json
import os
import pickle

class Sampling(Layer):
    def call(self, inputs):
        mu, log_var = inputs
        epsilon = K.random_normal(shape=K.shape(mu), mean=0., stddev=1.)
        return mu + K.exp(log_var / 2) * epsilon


class VAEModel(Model):
    def __init__(self, encoder, decoder, r_loss_factor, **kwargs):
        super(VAEModel, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.r_loss_factor = r_loss_factor
        self.built = True

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.square(data - reconstruction), axis = [1,2,3]
            )
            reconstruction_loss *= self.r_loss_factor
            kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            kl_loss = tf.reduce_sum(kl_loss, axis = 1)
            kl_loss *= -0.5
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }

    def call(self,inputs):
        latent = self.encoder(inputs)
        return self.decoder(latent)





class VariationalAutoencoder():
    def __init__(self
        , input_dim
        , encoder_conv_filters
        , encoder_conv_kernel_size
        , encoder_conv_strides
        , decoder_conv_t_filters
        , decoder_conv_t_kernel_size
        , decoder_conv_t_strides
        , z_dim
        , r_loss_factor
        , use_batch_norm = False
        , use_dropout= False
        ):

        self.name = 'variational_autoencoder'

        self.input_dim = input_dim
        self.encoder_conv_filters = encoder_conv_filters
        self.encoder_conv_kernel_size = encoder_conv_kernel_size
        self.encoder_conv_strides = encoder_conv_strides
        self.decoder_conv_t_filters = decoder_conv_t_filters
        self.decoder_conv_t_kernel_size = decoder_conv_t_kernel_size
        self.decoder_conv_t_strides = decoder_conv_t_strides
        self.z_dim = z_dim
        self.r_loss_factor = r_loss_factor

        self.use_batch_norm = use_batch_norm
        self.use_dropout = use_dropout

        self.n_layers_encoder = len(encoder_conv_filters)
        self.n_layers_decoder = len(decoder_conv_t_filters)

        self._build()

    def _build(self):
        
        ### THE ENCODER
        encoder_input = Input(shape=self.input_dim, name='encoder_input')

        x = encoder_input

        for i in range(self.n_layers_encoder):
            conv_layer = Conv2D(
                filters = self.encoder_conv_filters[i]
                , kernel_size = self.encoder_conv_kernel_size[i]
                , strides = self.encoder_conv_strides[i]
                , padding = 'same'
                , name = 'encoder_conv_' + str(i)
                )

            x = conv_layer(x)

            if self.use_batch_norm:
                x = BatchNormalization()(x)

            x = LeakyReLU()(x)

            if self.use_dropout:
                x = Dropout(rate = 0.25)(x)

        shape_before_flattening = K.int_shape(x)[1:]

        x = Flatten()(x)
        self.mu = Dense(self.z_dim, name='mu')(x)
        self.log_var = Dense(self.z_dim, name='log_var')(x)

        self.z = Sampling(name='encoder_output')([self.mu, self.log_var])

        self.encoder = Model(encoder_input, [self.mu, self.log_var, self.z], name = 'encoder')
        
        

        ### THE DECODER

        decoder_input = Input(shape=(self.z_dim,), name='decoder_input')

        x = Dense(np.prod(shape_before_flattening))(decoder_input)
        x = Reshape(shape_before_flattening)(x)

        for i in range(self.n_layers_decoder):
            conv_t_layer = Conv2DTranspose(
                filters = self.decoder_conv_t_filters[i]
                , kernel_size = self.decoder_conv_t_kernel_size[i]
                , strides = self.decoder_conv_t_strides[i]
                , padding = 'same'
                , name = 'decoder_conv_t_' + str(i)
                )

            x = conv_t_layer(x)

            if i < self.n_layers_decoder - 1:
                if self.use_batch_norm:
                    x = BatchNormalization()(x)
                x = LeakyReLU()(x)
                if self.use_dropout:
                    x = Dropout(rate = 0.25)(x)
            else:
                x = Activation('sigmoid')(x)

            

        decoder_output = x

        self.decoder = Model(decoder_input, decoder_output, name = 'decoder')

        ### THE FULL VAE

        self.model = VAEModel(self.encoder, self.decoder, self.r_loss_factor)



    def compile(self, learning_rate):
        self.learning_rate = learning_rate
        optimizer = Adam(lr=learning_rate)
        self.model.compile(optimizer=optimizer)


    def save(self, folder):

        if not os.path.exists(folder):
            os.makedirs(folder)
            os.makedirs(os.path.join(folder, 'viz'))
            os.makedirs(os.path.join(folder, 'weights'))
            os.makedirs(os.path.join(folder, 'images'))

        with open(os.path.join(folder, 'params.pkl'), 'wb') as f:
            pickle.dump([
                self.input_dim
                , self.encoder_conv_filters
                , self.encoder_conv_kernel_size
                , self.encoder_conv_strides
                , self.decoder_conv_t_filters
                , self.decoder_conv_t_kernel_size
                , self.decoder_conv_t_strides
                , self.z_dim
                , self.use_batch_norm
                , self.use_dropout
                ], f)

        self.plot_model(folder)


    def load_weights(self, filepath):
        self.model.load_weights(filepath)

    def train(self, x_train, batch_size, epochs, run_folder, print_every_n_batches = 100, initial_epoch = 0, lr_decay = 1):

        custom_callback = CustomCallback(run_folder, print_every_n_batches, initial_epoch, self)
        lr_sched = step_decay_schedule(initial_lr=self.learning_rate, decay_factor=lr_decay, step_size=1)
        
        # checkpoint_filepath=os.path.join(run_folder, "weights/weights-{epoch:03d}-{loss:.2f}.h5")
        # checkpoint_filepath=os.path.join(run_folder, "weights/weights.h5")
        # checkpoint1 = ModelCheckpoint(checkpoint_filepath, save_weights_only = True, verbose=1)
        checkpoint2 = ModelCheckpoint(os.path.join(run_folder, 'weights/weights.h5'), save_weights_only = True, verbose=1)

        callbacks_list = [checkpoint2, custom_callback, lr_sched]

        self.model.fit(     
            x_train
            , x_train
            , batch_size = batch_size
            , shuffle = True
            , epochs = epochs
            , initial_epoch = initial_epoch
            , callbacks = callbacks_list
        )



    def train_with_generator(self, data_flow, epochs, steps_per_epoch, run_folder, print_every_n_batches = 100, initial_epoch = 0, lr_decay = 1, ):

        custom_callback = CustomCallback(run_folder, print_every_n_batches, initial_epoch, self)
        lr_sched = step_decay_schedule(initial_lr=self.learning_rate, decay_factor=lr_decay, step_size=1)

        # checkpoint_filepath=os.path.join(run_folder, "weights/weights-{epoch:03d}-{loss:.2f}.h5")
        # checkpoint_filepath=os.path.join(run_folder, "weights/weights-{epoch:02d}.h5")
        # checkpoint_filepath=os.path.join(run_folder, "weights/weights.h5")
        # checkpoint1 = ModelCheckpoint(checkpoint_filepath, save_weights_only = True, verbose=1)
        checkpoint2 = ModelCheckpoint(os.path.join(run_folder, 'weights/weights.h5'), save_weights_only = True, verbose=1)

        callbacks_list = [checkpoint2, custom_callback, lr_sched]

        self.model.save_weights(os.path.join(run_folder, 'weights/weights.h5'))


        self.model.fit(
            data_flow
            , shuffle = True
            , epochs = epochs
            , initial_epoch = initial_epoch
            , callbacks = callbacks_list
            , steps_per_epoch=steps_per_epoch 
            )




    
    def plot_model(self, run_folder):
        plot_model(self.model, to_file=os.path.join(run_folder ,'viz/model.png'), show_shapes = True, show_layer_names = True)
        plot_model(self.encoder, to_file=os.path.join(run_folder ,'viz/encoder.png'), show_shapes = True, show_layer_names = True)
        plot_model(self.decoder, to_file=os.path.join(run_folder ,'viz/decoder.png'), show_shapes = True, show_layer_names = True)

# %%
#@title Loaders.py

import pickle
import os

from tensorflow.keras.datasets import mnist, cifar100,cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, save_img, img_to_array

import pandas as pd
from PIL import Image
import numpy as np
from os import walk, getcwd
import h5py

import imageio
from glob import glob

from tensorflow.keras.applications import vgg19
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical

import pdb


class ImageLabelLoader():
    def __init__(self, image_folder, target_size):
        self.image_folder = image_folder
        self.target_size = target_size

    def build(self, att, batch_size, label = None):

        data_gen = ImageDataGenerator(rescale=1./255)
        if label:
            data_flow = data_gen.flow_from_dataframe(
                att
                , self.image_folder
                , x_col='image_id'
                , y_col=label
                , target_size=self.target_size 
                , class_mode='other'
                , batch_size=batch_size
                , shuffle=True
            )
        else:
            data_flow = data_gen.flow_from_dataframe(
                att
                , self.image_folder
                , x_col='image_id'
                , target_size=self.target_size 
                , class_mode='input'
                , batch_size=batch_size
                , shuffle=True
            )

        return data_flow




class DataLoader():
    def __init__(self, dataset_name, img_res=(256, 256)):
        self.dataset_name = dataset_name
        self.img_res = img_res

    def load_data(self, domain, batch_size=1, is_testing=False):
        data_type = "train%s" % domain if not is_testing else "test%s" % domain
        path = glob('./data/%s/%s/*' % (self.dataset_name, data_type))

        batch_images = np.random.choice(path, size=batch_size)

        imgs = []
        for img_path in batch_images:
            img = self.imread(img_path)
            if not is_testing:
                img = np.array(Image.fromarray(img).resize(self.img_res))

                if np.random.random() > 0.5:
                    img = np.fliplr(img)
            else:
                img = np.array(Image.fromarray(img).resize(self.img_res))
            imgs.append(img)

        imgs = np.array(imgs)/127.5 - 1.

        return imgs

    def load_batch(self, batch_size=1, is_testing=False):
        data_type = "train" if not is_testing else "val"
        path_A = glob('./data/%s/%sA/*' % (self.dataset_name, data_type))
        path_B = glob('./data/%s/%sB/*' % (self.dataset_name, data_type))

        self.n_batches = int(min(len(path_A), len(path_B)) / batch_size)
        total_samples = self.n_batches * batch_size

        # Sample n_batches * batch_size from each path list so that model sees all
        # samples from both domains
        path_A = np.random.choice(path_A, total_samples, replace=False)
        path_B = np.random.choice(path_B, total_samples, replace=False)

        for i in range(self.n_batches-1):
            batch_A = path_A[i*batch_size:(i+1)*batch_size]
            batch_B = path_B[i*batch_size:(i+1)*batch_size]
            imgs_A, imgs_B = [], []
            for img_A, img_B in zip(batch_A, batch_B):
                img_A = self.imread(img_A)
                img_B = self.imread(img_B)

                img_A = np.array(Image.fromarray(img_A).resize(self.img_res))
                img_B = np.array(Image.fromarray(img_B).resize(self.img_res))

                if not is_testing and np.random.random() > 0.5:
                    img_A = np.fliplr(img_A)
                    img_B = np.fliplr(img_B)

                imgs_A.append(img_A)
                imgs_B.append(img_B)

            imgs_A = np.array(imgs_A)/127.5 - 1.
            imgs_B = np.array(imgs_B)/127.5 - 1.

            yield imgs_A, imgs_B

    def load_img(self, path):
        img = self.imread(path)
        img = np.array(Image.fromarray(img).resize(self.img_res))
        img = img/127.5 - 1.
        return img[np.newaxis, :, :, :]

    def imread(self, path):
        return imageio.imread(path, pilmode='RGB').astype(np.uint8)




def load_model(model_class, folder):
    
    with open(os.path.join(folder, 'params.pkl'), 'rb') as f:
        params = pickle.load(f)

    model = model_class(*params)

    model.load_weights(os.path.join(folder, 'weights/weights.h5'))

    return model


def load_mnist():
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    x_train = x_train.astype('float32') / 255.
    x_train = x_train.reshape(x_train.shape + (1,))
    x_test = x_test.astype('float32') / 255.
    x_test = x_test.reshape(x_test.shape + (1,))

    return (x_train, y_train), (x_test, y_test)

def load_mnist_gan():
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    x_train = (x_train.astype('float32') - 127.5) / 127.5
    x_train = x_train.reshape(x_train.shape + (1,))
    x_test = (x_test.astype('float32') - 127.5) / 127.5
    x_test = x_test.reshape(x_test.shape + (1,))

    return (x_train, y_train), (x_test, y_test)



def load_fashion_mnist(input_rows, input_cols, path='./data/fashion/fashion-mnist_train.csv'):
    #read the csv data
    df = pd.read_csv(path)
    #extract the image pixels
    X_train = df.drop(columns = ['label'])
    X_train = X_train.values
    X_train = (X_train.astype('float32') - 127.5) / 127.5
    X_train = X_train.reshape(X_train.shape[0], input_rows, input_cols, 1)
    #extract the labels
    y_train = df['label'].values
    
    return X_train, y_train

def load_safari(folder):

    mypath = os.path.join("./data", folder)
    txt_name_list = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        for f in filenames:
            if f != '.DS_Store':
                txt_name_list.append(f)
                break

    slice_train = int(80000/len(txt_name_list))  ###Setting value to be 80000 for the final dataset
    i = 0
    seed = np.random.randint(1, 10e6)

    for txt_name in txt_name_list:
        txt_path = os.path.join(mypath,txt_name)
        x = np.load(txt_path)
        x = (x.astype('float32') - 127.5) / 127.5
        # x = x.astype('float32') / 255.0
        
        x = x.reshape(x.shape[0], 28, 28, 1)
        
        y = [i] * len(x)  
        np.random.seed(seed)
        np.random.shuffle(x)
        np.random.seed(seed)
        np.random.shuffle(y)
        x = x[:slice_train]
        y = y[:slice_train]
        if i != 0: 
            xtotal = np.concatenate((x,xtotal), axis=0)
            ytotal = np.concatenate((y,ytotal), axis=0)
        else:
            xtotal = x
            ytotal = y
        i += 1
        
    return xtotal, ytotal



def load_cifar(label, num):
    if num == 10:
        (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    else:
        (x_train, y_train), (x_test, y_test) = cifar100.load_data(label_mode = 'fine')

    train_mask = [y[0]==label for y in y_train]
    test_mask = [y[0]==label for y in y_test]

    x_data = np.concatenate([x_train[train_mask], x_test[test_mask]])
    y_data = np.concatenate([y_train[train_mask], y_test[test_mask]])

    x_data = (x_data.astype('float32') - 127.5) / 127.5
 
    return (x_data, y_data)


def load_celeb(data_name, image_size, batch_size):
    data_folder = os.path.join("./data", data_name)

    data_gen = ImageDataGenerator(preprocessing_function=lambda x: (x.astype('float32') - 127.5) / 127.5)

    x_train = data_gen.flow_from_directory(data_folder
                                            , target_size = (image_size,image_size)
                                            , batch_size = batch_size
                                            , shuffle = True
                                            , class_mode = 'input'
                                            , subset = "training"
                                                )

    return x_train


def load_music(data_name, filename, n_bars, n_steps_per_bar):
    file = os.path.join("./data", data_name, filename)

    with np.load(file, encoding='bytes', allow_pickle = True) as f:
        data = f['train']

    data_ints = []

    for x in data:
        counter = 0
        cont = True
        while cont:
            if not np.any(np.isnan(x[counter:(counter+4)])):
                cont = False
            else:
                counter += 4

        if n_bars * n_steps_per_bar < x.shape[0]:
            data_ints.append(x[counter:(counter + (n_bars * n_steps_per_bar)),:])


    data_ints = np.array(data_ints)

    n_songs = data_ints.shape[0]
    n_tracks = data_ints.shape[2]

    data_ints = data_ints.reshape([n_songs, n_bars, n_steps_per_bar, n_tracks])

    max_note = 83

    where_are_NaNs = np.isnan(data_ints)
    data_ints[where_are_NaNs] = max_note + 1
    max_note = max_note + 1

    data_ints = data_ints.astype(int)

    num_classes = max_note + 1

    
    data_binary = np.eye(num_classes)[data_ints]
    data_binary[data_binary==0] = -1
    data_binary = np.delete(data_binary, max_note,-1)

    data_binary = data_binary.transpose([0,1,2, 4,3])
    
    

    

    return data_binary, data_ints, data


def preprocess_image(data_name, file, img_nrows, img_ncols):

    image_path = os.path.join('./data', data_name, file)

    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
# run params
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

os.makedirs(RUN_FOLDER,exist_ok = True)
os.makedirs(os.path.join(RUN_FOLDER, 'viz'),exist_ok = True)
os.makedirs(os.path.join(RUN_FOLDER, 'images'),exist_ok = True)
os.makedirs(os.path.join(RUN_FOLDER, 'weights'),exist_ok = True)
mode =  'build' #'load' #

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
vae = VariationalAutoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64, 64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
    , r_loss_factor = 1000
)
LEARNING_RATE = 0.0005
R_LOSS_FACTOR = 1000
vae.compile(LEARNING_RATE)
if mode == 'build':
    vae.save(RUN_FOLDER)
else:
    vae.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
vae.encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 28, 28, 1)]  0           []
#
#  encoder_conv_0 (Conv2D)        (None, 28, 28, 32)   320         ['encoder_input[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 28, 28, 32)   0           ['encoder_conv_0[0][0]']
#
#  encoder_conv_1 (Conv2D)        (None, 14, 14, 64)   18496       ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 14, 14, 64)   0           ['encoder_conv_1[0][0]']
#
#  encoder_conv_2 (Conv2D)        (None, 7, 7, 64)     36928       ['leaky_re_lu_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 7, 7, 64)     0           ['encoder_conv_2[0][0]']
#
#  encoder_conv_3 (Conv2D)        (None, 7, 7, 64)     36928       ['leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 7, 7, 64)     0           ['encoder_conv_3[0][0]']
#
#  flatten (Flatten)              (None, 3136)         0           ['leaky_re_lu_3[0][0]']
#
#  mu (Dense)                     (None, 2)            6274        ['flatten[0][0]']
#
#  log_var (Dense)                (None, 2)            6274        ['flatten[0][0]']
#
#  encoder_output (Sampling)      (None, 2)            0           ['mu[0][0]',
#                                                                   'log_var[0][0]']
#
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 2)]               0
#
#  dense (Dense)               (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  decoder_conv_t_0 (Conv2DTra  (None, 7, 7, 64)         36928
#  nspose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  decoder_conv_t_1 (Conv2DTra  (None, 14, 14, 64)       36928
#  nspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  decoder_conv_t_2 (Conv2DTra  (None, 28, 28, 32)       18464
#  nspose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 28, 28, 32)        0
#
#  decoder_conv_t_3 (Conv2DTra  (None, 28, 28, 1)        289
#  nspose)
#
#  activation (Activation)     (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE = 32
EPOCHS = 200
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 0

# %%
# tf.compat.v1.enable_eager_execution(
#     config=None, device_policy=None, execution_mode=None
# )
# from tensorflow.python.framework.ops import disable_eager_execution
# disable_eager_execution()

# ?
# vae.compile()

# %%
vae.train(     
    x_train
    , batch_size = BATCH_SIZE
    , epochs = EPOCHS
    , run_folder = RUN_FOLDER
    , print_every_n_batches = PRINT_EVERY_N_BATCHES
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# Epoch 1/200
#    4/1875 [..............................] - ETA: 32s - loss: 229.9547 - reconstruction_loss: 229.9515 - kl_loss: 0.0031         WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0081s vs `on_train_batch_end` time: 0.0486s). Check your callbacks.
# 1874/1875 [============================>.] - ETA: 0s - loss: 58.2073 - reconstruction_loss: 54.9302 - kl_loss: 3.2771
# Epoch 00001: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 53s 12ms/step - loss: 58.2068 - reconstruction_loss: 54.9293 - kl_loss: 3.2775 - lr: 5.0000e-04
# Epoch 2/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 51.6106 - reconstruction_loss: 47.6091 - kl_loss: 4.0015
# Epoch 00002: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 22s 12ms/step - loss: 51.6120 - reconstruction_loss: 47.6104 - kl_loss: 4.0016 - lr: 5.0000e-04
# Epoch 3/200
# 1875/1875 [==============================] - ETA: 0s - loss: 50.0264 - reconstruction_loss: 45.7040 - kl_loss: 4.3225
# Epoch 00003: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 50.0271 - reconstruction_loss: 45.7045 - kl_loss: 4.3226 - lr: 5.0000e-04
# Epoch 4/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 49.1044 - reconstruction_loss: 44.5954 - kl_loss: 4.5090
# Epoch 00004: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 22s 12ms/step - loss: 49.0983 - reconstruction_loss: 44.5888 - kl_loss: 4.5094 - lr: 5.0000e-04
# Epoch 5/200
# 1875/1875 [==============================] - ETA: 0s - loss: 48.4361 - reconstruction_loss: 43.8147 - kl_loss: 4.6214
# Epoch 00005: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 48.4363 - reconstruction_loss: 43.8149 - kl_loss: 4.6214 - lr: 5.0000e-04
# Epoch 6/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 47.9611 - reconstruction_loss: 43.2749 - kl_loss: 4.6862
# Epoch 00006: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 47.9567 - reconstruction_loss: 43.2704 - kl_loss: 4.6864 - lr: 5.0000e-04
# Epoch 7/200
# 1875/1875 [==============================] - ETA: 0s - loss: 47.6185 - reconstruction_loss: 42.8705 - kl_loss: 4.7480
# Epoch 00007: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 47.6202 - reconstruction_loss: 42.8721 - kl_loss: 4.7481 - lr: 5.0000e-04
# Epoch 8/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 47.3054 - reconstruction_loss: 42.5092 - kl_loss: 4.7962
# Epoch 00008: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 47.3099 - reconstruction_loss: 42.5133 - kl_loss: 4.7966 - lr: 5.0000e-04
# Epoch 9/200
# 1875/1875 [==============================] - ETA: 0s - loss: 47.1023 - reconstruction_loss: 42.2442 - kl_loss: 4.8581
# Epoch 00009: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 47.1018 - reconstruction_loss: 42.2438 - kl_loss: 4.8580 - lr: 5.0000e-04
# Epoch 10/200
# 1875/1875 [==============================] - ETA: 0s - loss: 46.9240 - reconstruction_loss: 42.0529 - kl_loss: 4.8710
# Epoch 00010: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 46.9230 - reconstruction_loss: 42.0520 - kl_loss: 4.8710 - lr: 5.0000e-04
# Epoch 11/200
# 1875/1875 [==============================] - ETA: 0s - loss: 46.7592 - reconstruction_loss: 41.8579 - kl_loss: 4.9013
# Epoch 00011: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 46.7584 - reconstruction_loss: 41.8571 - kl_loss: 4.9014 - lr: 5.0000e-04
# Epoch 12/200
# 1875/1875 [==============================] - ETA: 0s - loss: 46.6237 - reconstruction_loss: 41.6941 - kl_loss: 4.9296
# Epoch 00012: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 46.6239 - reconstruction_loss: 41.6943 - kl_loss: 4.9296 - lr: 5.0000e-04
# Epoch 13/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 46.4569 - reconstruction_loss: 41.5132 - kl_loss: 4.9437
# Epoch 00013: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 46.4570 - reconstruction_loss: 41.5133 - kl_loss: 4.9437 - lr: 5.0000e-04
# Epoch 14/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 46.3357 - reconstruction_loss: 41.3787 - kl_loss: 4.9570
# Epoch 00014: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 46.3409 - reconstruction_loss: 41.3833 - kl_loss: 4.9576 - lr: 5.0000e-04
# Epoch 15/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 46.2562 - reconstruction_loss: 41.2675 - kl_loss: 4.9887
# Epoch 00015: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 46.2549 - reconstruction_loss: 41.2665 - kl_loss: 4.9884 - lr: 5.0000e-04
# Epoch 16/200
# 1875/1875 [==============================] - ETA: 0s - loss: 46.1606 - reconstruction_loss: 41.1532 - kl_loss: 5.0074
# Epoch 00016: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 46.1567 - reconstruction_loss: 41.1491 - kl_loss: 5.0076 - lr: 5.0000e-04
# Epoch 17/200
# 1875/1875 [==============================] - ETA: 0s - loss: 46.0466 - reconstruction_loss: 41.0326 - kl_loss: 5.0140
# Epoch 00017: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 46.0482 - reconstruction_loss: 41.0342 - kl_loss: 5.0140 - lr: 5.0000e-04
# Epoch 18/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 45.9464 - reconstruction_loss: 40.9294 - kl_loss: 5.0170
# Epoch 00018: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.9537 - reconstruction_loss: 40.9365 - kl_loss: 5.0171 - lr: 5.0000e-04
# Epoch 19/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 45.8931 - reconstruction_loss: 40.8402 - kl_loss: 5.0528
# Epoch 00019: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.8946 - reconstruction_loss: 40.8417 - kl_loss: 5.0528 - lr: 5.0000e-04
# Epoch 20/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 45.7959 - reconstruction_loss: 40.7458 - kl_loss: 5.0502
# Epoch 00020: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.7998 - reconstruction_loss: 40.7497 - kl_loss: 5.0501 - lr: 5.0000e-04
# Epoch 21/200
# 1875/1875 [==============================] - ETA: 0s - loss: 45.7337 - reconstruction_loss: 40.6765 - kl_loss: 5.0572
# Epoch 00021: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.7311 - reconstruction_loss: 40.6738 - kl_loss: 5.0573 - lr: 5.0000e-04
# Epoch 22/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 45.6752 - reconstruction_loss: 40.5983 - kl_loss: 5.0769
# Epoch 00022: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.6757 - reconstruction_loss: 40.5986 - kl_loss: 5.0771 - lr: 5.0000e-04
# Epoch 23/200
# 1875/1875 [==============================] - ETA: 0s - loss: 45.6088 - reconstruction_loss: 40.5228 - kl_loss: 5.0860
# Epoch 00023: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.6078 - reconstruction_loss: 40.5219 - kl_loss: 5.0859 - lr: 5.0000e-04
# Epoch 24/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 45.5945 - reconstruction_loss: 40.5156 - kl_loss: 5.0789
# Epoch 00024: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.5938 - reconstruction_loss: 40.5151 - kl_loss: 5.0787 - lr: 5.0000e-04
# Epoch 25/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 45.5100 - reconstruction_loss: 40.4213 - kl_loss: 5.0887
# Epoch 00025: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.5117 - reconstruction_loss: 40.4230 - kl_loss: 5.0886 - lr: 5.0000e-04
# Epoch 26/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 45.4649 - reconstruction_loss: 40.3735 - kl_loss: 5.0914
# Epoch 00026: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.4678 - reconstruction_loss: 40.3762 - kl_loss: 5.0916 - lr: 5.0000e-04
# Epoch 27/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 45.4206 - reconstruction_loss: 40.3114 - kl_loss: 5.1092
# Epoch 00027: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.4167 - reconstruction_loss: 40.3076 - kl_loss: 5.1091 - lr: 5.0000e-04
# Epoch 28/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 45.3920 - reconstruction_loss: 40.2749 - kl_loss: 5.1172
# Epoch 00028: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.3969 - reconstruction_loss: 40.2799 - kl_loss: 5.1170 - lr: 5.0000e-04
# Epoch 29/200
# 1875/1875 [==============================] - ETA: 0s - loss: 45.3273 - reconstruction_loss: 40.2040 - kl_loss: 5.1233
# Epoch 00029: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.3253 - reconstruction_loss: 40.2020 - kl_loss: 5.1234 - lr: 5.0000e-04
# Epoch 30/200
# 1875/1875 [==============================] - ETA: 0s - loss: 45.2599 - reconstruction_loss: 40.1386 - kl_loss: 5.1213
# Epoch 00030: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.2597 - reconstruction_loss: 40.1383 - kl_loss: 5.1214 - lr: 5.0000e-04
# Epoch 31/200
# 1875/1875 [==============================] - ETA: 0s - loss: 45.2231 - reconstruction_loss: 40.0966 - kl_loss: 5.1265
# Epoch 00031: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.2216 - reconstruction_loss: 40.0951 - kl_loss: 5.1265 - lr: 5.0000e-04
# Epoch 32/200
# 1875/1875 [==============================] - ETA: 0s - loss: 45.1871 - reconstruction_loss: 40.0513 - kl_loss: 5.1359
# Epoch 00032: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.1843 - reconstruction_loss: 40.0482 - kl_loss: 5.1360 - lr: 5.0000e-04
# Epoch 33/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 45.1765 - reconstruction_loss: 40.0365 - kl_loss: 5.1400
# Epoch 00033: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.1724 - reconstruction_loss: 40.0326 - kl_loss: 5.1398 - lr: 5.0000e-04
# Epoch 34/200
# 1875/1875 [==============================] - ETA: 0s - loss: 45.1316 - reconstruction_loss: 39.9840 - kl_loss: 5.1476
# Epoch 00034: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.1297 - reconstruction_loss: 39.9822 - kl_loss: 5.1475 - lr: 5.0000e-04
# Epoch 35/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 45.0959 - reconstruction_loss: 39.9392 - kl_loss: 5.1567
# Epoch 00035: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.0982 - reconstruction_loss: 39.9413 - kl_loss: 5.1570 - lr: 5.0000e-04
# Epoch 36/200
# 1875/1875 [==============================] - ETA: 0s - loss: 45.0524 - reconstruction_loss: 39.8918 - kl_loss: 5.1606
# Epoch 00036: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 45.0496 - reconstruction_loss: 39.8889 - kl_loss: 5.1606 - lr: 5.0000e-04
# Epoch 37/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 44.9863 - reconstruction_loss: 39.8302 - kl_loss: 5.1561
# Epoch 00037: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.9892 - reconstruction_loss: 39.8329 - kl_loss: 5.1563 - lr: 5.0000e-04
# Epoch 38/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.9722 - reconstruction_loss: 39.7979 - kl_loss: 5.1742
# Epoch 00038: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.9728 - reconstruction_loss: 39.7985 - kl_loss: 5.1743 - lr: 5.0000e-04
# Epoch 39/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.9784 - reconstruction_loss: 39.7958 - kl_loss: 5.1826
# Epoch 00039: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.9793 - reconstruction_loss: 39.7967 - kl_loss: 5.1826 - lr: 5.0000e-04
# Epoch 40/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.9279 - reconstruction_loss: 39.7585 - kl_loss: 5.1693
# Epoch 00040: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.9281 - reconstruction_loss: 39.7588 - kl_loss: 5.1694 - lr: 5.0000e-04
# Epoch 41/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.9094 - reconstruction_loss: 39.7211 - kl_loss: 5.1883
# Epoch 00041: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.9090 - reconstruction_loss: 39.7207 - kl_loss: 5.1883 - lr: 5.0000e-04
# Epoch 42/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 44.8745 - reconstruction_loss: 39.6802 - kl_loss: 5.1942
# Epoch 00042: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.8660 - reconstruction_loss: 39.6715 - kl_loss: 5.1945 - lr: 5.0000e-04
# Epoch 43/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.8307 - reconstruction_loss: 39.6363 - kl_loss: 5.1944
# Epoch 00043: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.8294 - reconstruction_loss: 39.6350 - kl_loss: 5.1944 - lr: 5.0000e-04
# Epoch 44/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.8073 - reconstruction_loss: 39.6061 - kl_loss: 5.2012
# Epoch 00044: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.8069 - reconstruction_loss: 39.6058 - kl_loss: 5.2012 - lr: 5.0000e-04
# Epoch 45/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 44.7857 - reconstruction_loss: 39.5842 - kl_loss: 5.2015
# Epoch 00045: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.7850 - reconstruction_loss: 39.5836 - kl_loss: 5.2014 - lr: 5.0000e-04
# Epoch 46/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 44.7539 - reconstruction_loss: 39.5547 - kl_loss: 5.1992
# Epoch 00046: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.7510 - reconstruction_loss: 39.5514 - kl_loss: 5.1996 - lr: 5.0000e-04
# Epoch 47/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.7414 - reconstruction_loss: 39.5367 - kl_loss: 5.2046
# Epoch 00047: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.7365 - reconstruction_loss: 39.5318 - kl_loss: 5.2048 - lr: 5.0000e-04
# Epoch 48/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.7270 - reconstruction_loss: 39.5258 - kl_loss: 5.2012
# Epoch 00048: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.7235 - reconstruction_loss: 39.5222 - kl_loss: 5.2013 - lr: 5.0000e-04
# Epoch 49/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 44.6805 - reconstruction_loss: 39.4626 - kl_loss: 5.2179
# Epoch 00049: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.6849 - reconstruction_loss: 39.4670 - kl_loss: 5.2178 - lr: 5.0000e-04
# Epoch 50/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 44.6652 - reconstruction_loss: 39.4433 - kl_loss: 5.2219
# Epoch 00050: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.6662 - reconstruction_loss: 39.4441 - kl_loss: 5.2220 - lr: 5.0000e-04
# Epoch 51/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.6476 - reconstruction_loss: 39.4156 - kl_loss: 5.2320
# Epoch 00051: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.6462 - reconstruction_loss: 39.4142 - kl_loss: 5.2319 - lr: 5.0000e-04
# Epoch 52/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 44.6053 - reconstruction_loss: 39.3837 - kl_loss: 5.2216
# Epoch 00052: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.6109 - reconstruction_loss: 39.3893 - kl_loss: 5.2216 - lr: 5.0000e-04
# Epoch 53/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.6056 - reconstruction_loss: 39.3913 - kl_loss: 5.2142
# Epoch 00053: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.6030 - reconstruction_loss: 39.3888 - kl_loss: 5.2142 - lr: 5.0000e-04
# Epoch 54/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.6063 - reconstruction_loss: 39.3717 - kl_loss: 5.2346
# Epoch 00054: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.6036 - reconstruction_loss: 39.3691 - kl_loss: 5.2345 - lr: 5.0000e-04
# Epoch 55/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.5593 - reconstruction_loss: 39.3185 - kl_loss: 5.2408
# Epoch 00055: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.5567 - reconstruction_loss: 39.3161 - kl_loss: 5.2406 - lr: 5.0000e-04
# Epoch 56/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.5404 - reconstruction_loss: 39.3034 - kl_loss: 5.2370
# Epoch 00056: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.5437 - reconstruction_loss: 39.3066 - kl_loss: 5.2371 - lr: 5.0000e-04
# Epoch 57/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.5302 - reconstruction_loss: 39.2832 - kl_loss: 5.2469
# Epoch 00057: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.5298 - reconstruction_loss: 39.2828 - kl_loss: 5.2470 - lr: 5.0000e-04
# Epoch 58/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.5222 - reconstruction_loss: 39.2786 - kl_loss: 5.2436
# Epoch 00058: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.5242 - reconstruction_loss: 39.2808 - kl_loss: 5.2435 - lr: 5.0000e-04
# Epoch 59/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 44.5027 - reconstruction_loss: 39.2508 - kl_loss: 5.2519
# Epoch 00059: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.4959 - reconstruction_loss: 39.2439 - kl_loss: 5.2520 - lr: 5.0000e-04
# Epoch 60/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 44.4458 - reconstruction_loss: 39.1996 - kl_loss: 5.2462
# Epoch 00060: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.4513 - reconstruction_loss: 39.2059 - kl_loss: 5.2453 - lr: 5.0000e-04
# Epoch 61/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 44.4667 - reconstruction_loss: 39.2109 - kl_loss: 5.2558
# Epoch 00061: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.4702 - reconstruction_loss: 39.2142 - kl_loss: 5.2560 - lr: 5.0000e-04
# Epoch 62/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.4293 - reconstruction_loss: 39.1787 - kl_loss: 5.2506
# Epoch 00062: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.4319 - reconstruction_loss: 39.1813 - kl_loss: 5.2506 - lr: 5.0000e-04
# Epoch 63/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.4389 - reconstruction_loss: 39.1743 - kl_loss: 5.2646
# Epoch 00063: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.4390 - reconstruction_loss: 39.1743 - kl_loss: 5.2647 - lr: 5.0000e-04
# Epoch 64/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 44.4091 - reconstruction_loss: 39.1477 - kl_loss: 5.2615
# Epoch 00064: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.4054 - reconstruction_loss: 39.1439 - kl_loss: 5.2615 - lr: 5.0000e-04
# Epoch 65/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.3600 - reconstruction_loss: 39.0988 - kl_loss: 5.2612
# Epoch 00065: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.3603 - reconstruction_loss: 39.0991 - kl_loss: 5.2612 - lr: 5.0000e-04
# Epoch 66/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.3417 - reconstruction_loss: 39.0789 - kl_loss: 5.2627
# Epoch 00066: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.3436 - reconstruction_loss: 39.0809 - kl_loss: 5.2627 - lr: 5.0000e-04
# Epoch 67/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.3474 - reconstruction_loss: 39.0860 - kl_loss: 5.2614
# Epoch 00067: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.3491 - reconstruction_loss: 39.0878 - kl_loss: 5.2613 - lr: 5.0000e-04
# Epoch 68/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.3377 - reconstruction_loss: 39.0660 - kl_loss: 5.2716
# Epoch 00068: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.3377 - reconstruction_loss: 39.0662 - kl_loss: 5.2715 - lr: 5.0000e-04
# Epoch 69/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.3200 - reconstruction_loss: 39.0564 - kl_loss: 5.2636
# Epoch 00069: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.3308 - reconstruction_loss: 39.0672 - kl_loss: 5.2636 - lr: 5.0000e-04
# Epoch 70/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 44.3070 - reconstruction_loss: 39.0281 - kl_loss: 5.2788
# Epoch 00070: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.3101 - reconstruction_loss: 39.0311 - kl_loss: 5.2790 - lr: 5.0000e-04
# Epoch 71/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.2872 - reconstruction_loss: 39.0111 - kl_loss: 5.2762
# Epoch 00071: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.2858 - reconstruction_loss: 39.0097 - kl_loss: 5.2762 - lr: 5.0000e-04
# Epoch 72/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.2730 - reconstruction_loss: 38.9978 - kl_loss: 5.2752
# Epoch 00072: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.2745 - reconstruction_loss: 38.9993 - kl_loss: 5.2752 - lr: 5.0000e-04
# Epoch 73/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.2665 - reconstruction_loss: 38.9846 - kl_loss: 5.2819
# Epoch 00073: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.2611 - reconstruction_loss: 38.9791 - kl_loss: 5.2819 - lr: 5.0000e-04
# Epoch 74/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 44.2452 - reconstruction_loss: 38.9532 - kl_loss: 5.2920
# Epoch 00074: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.2471 - reconstruction_loss: 38.9552 - kl_loss: 5.2919 - lr: 5.0000e-04
# Epoch 75/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.2473 - reconstruction_loss: 38.9561 - kl_loss: 5.2912
# Epoch 00075: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.2461 - reconstruction_loss: 38.9547 - kl_loss: 5.2914 - lr: 5.0000e-04
# Epoch 76/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.2256 - reconstruction_loss: 38.9421 - kl_loss: 5.2835
# Epoch 00076: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.2197 - reconstruction_loss: 38.9363 - kl_loss: 5.2834 - lr: 5.0000e-04
# Epoch 77/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.1971 - reconstruction_loss: 38.9036 - kl_loss: 5.2935
# Epoch 00077: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.1943 - reconstruction_loss: 38.9011 - kl_loss: 5.2932 - lr: 5.0000e-04
# Epoch 78/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.1829 - reconstruction_loss: 38.8868 - kl_loss: 5.2961
# Epoch 00078: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.1852 - reconstruction_loss: 38.8890 - kl_loss: 5.2962 - lr: 5.0000e-04
# Epoch 79/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.1694 - reconstruction_loss: 38.8564 - kl_loss: 5.3131
# Epoch 00079: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.1708 - reconstruction_loss: 38.8578 - kl_loss: 5.3130 - lr: 5.0000e-04
# Epoch 80/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 44.1590 - reconstruction_loss: 38.8568 - kl_loss: 5.3022
# Epoch 00080: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.1566 - reconstruction_loss: 38.8545 - kl_loss: 5.3021 - lr: 5.0000e-04
# Epoch 81/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.1444 - reconstruction_loss: 38.8353 - kl_loss: 5.3091
# Epoch 00081: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.1429 - reconstruction_loss: 38.8338 - kl_loss: 5.3091 - lr: 5.0000e-04
# Epoch 82/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.1396 - reconstruction_loss: 38.8188 - kl_loss: 5.3208
# Epoch 00082: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.1353 - reconstruction_loss: 38.8147 - kl_loss: 5.3206 - lr: 5.0000e-04
# Epoch 83/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 44.1011 - reconstruction_loss: 38.7855 - kl_loss: 5.3156
# Epoch 00083: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.1071 - reconstruction_loss: 38.7917 - kl_loss: 5.3154 - lr: 5.0000e-04
# Epoch 84/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 44.0866 - reconstruction_loss: 38.7947 - kl_loss: 5.2920
# Epoch 00084: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.0815 - reconstruction_loss: 38.7892 - kl_loss: 5.2923 - lr: 5.0000e-04
# Epoch 85/200
# 1875/1875 [==============================] - ETA: 0s - loss: 44.0970 - reconstruction_loss: 38.7811 - kl_loss: 5.3159
# Epoch 00085: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.0974 - reconstruction_loss: 38.7816 - kl_loss: 5.3159 - lr: 5.0000e-04
# Epoch 86/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.0490 - reconstruction_loss: 38.7284 - kl_loss: 5.3206
# Epoch 00086: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.0427 - reconstruction_loss: 38.7223 - kl_loss: 5.3204 - lr: 5.0000e-04
# Epoch 87/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 44.0327 - reconstruction_loss: 38.7053 - kl_loss: 5.3274
# Epoch 00087: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.0367 - reconstruction_loss: 38.7093 - kl_loss: 5.3273 - lr: 5.0000e-04
# Epoch 88/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 44.0491 - reconstruction_loss: 38.7296 - kl_loss: 5.3196
# Epoch 00088: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.0440 - reconstruction_loss: 38.7240 - kl_loss: 5.3201 - lr: 5.0000e-04
# Epoch 89/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 43.9845 - reconstruction_loss: 38.6654 - kl_loss: 5.3191
# Epoch 00089: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.9821 - reconstruction_loss: 38.6633 - kl_loss: 5.3188 - lr: 5.0000e-04
# Epoch 90/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 44.0047 - reconstruction_loss: 38.6739 - kl_loss: 5.3308
# Epoch 00090: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 44.0113 - reconstruction_loss: 38.6805 - kl_loss: 5.3308 - lr: 5.0000e-04
# Epoch 91/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.9995 - reconstruction_loss: 38.6655 - kl_loss: 5.3339
# Epoch 00091: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 43.9976 - reconstruction_loss: 38.6637 - kl_loss: 5.3338 - lr: 5.0000e-04
# Epoch 92/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.9836 - reconstruction_loss: 38.6490 - kl_loss: 5.3346
# Epoch 00092: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 43.9826 - reconstruction_loss: 38.6479 - kl_loss: 5.3346 - lr: 5.0000e-04
# Epoch 93/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.9681 - reconstruction_loss: 38.6252 - kl_loss: 5.3429
# Epoch 00093: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.9650 - reconstruction_loss: 38.6219 - kl_loss: 5.3431 - lr: 5.0000e-04
# Epoch 94/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.9788 - reconstruction_loss: 38.6330 - kl_loss: 5.3458
# Epoch 00094: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.9772 - reconstruction_loss: 38.6313 - kl_loss: 5.3459 - lr: 5.0000e-04
# Epoch 95/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.9033 - reconstruction_loss: 38.5731 - kl_loss: 5.3301
# Epoch 00095: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 43.9064 - reconstruction_loss: 38.5762 - kl_loss: 5.3302 - lr: 5.0000e-04
# Epoch 96/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.9475 - reconstruction_loss: 38.5962 - kl_loss: 5.3513
# Epoch 00096: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 43.9503 - reconstruction_loss: 38.5989 - kl_loss: 5.3513 - lr: 5.0000e-04
# Epoch 97/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.9352 - reconstruction_loss: 38.5878 - kl_loss: 5.3474
# Epoch 00097: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.9326 - reconstruction_loss: 38.5852 - kl_loss: 5.3474 - lr: 5.0000e-04
# Epoch 98/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.8928 - reconstruction_loss: 38.5424 - kl_loss: 5.3503
# Epoch 00098: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.8948 - reconstruction_loss: 38.5446 - kl_loss: 5.3502 - lr: 5.0000e-04
# Epoch 99/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.8985 - reconstruction_loss: 38.5261 - kl_loss: 5.3724
# Epoch 00099: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.9019 - reconstruction_loss: 38.5296 - kl_loss: 5.3724 - lr: 5.0000e-04
# Epoch 100/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.8642 - reconstruction_loss: 38.5133 - kl_loss: 5.3509
# Epoch 00100: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.8666 - reconstruction_loss: 38.5157 - kl_loss: 5.3510 - lr: 5.0000e-04
# Epoch 101/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.8604 - reconstruction_loss: 38.4945 - kl_loss: 5.3659
# Epoch 00101: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.8660 - reconstruction_loss: 38.5002 - kl_loss: 5.3658 - lr: 5.0000e-04
# Epoch 102/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.8698 - reconstruction_loss: 38.5097 - kl_loss: 5.3601
# Epoch 00102: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.8715 - reconstruction_loss: 38.5112 - kl_loss: 5.3602 - lr: 5.0000e-04
# Epoch 103/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.8177 - reconstruction_loss: 38.4500 - kl_loss: 5.3677
# Epoch 00103: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.8167 - reconstruction_loss: 38.4489 - kl_loss: 5.3678 - lr: 5.0000e-04
# Epoch 104/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.8190 - reconstruction_loss: 38.4564 - kl_loss: 5.3625
# Epoch 00104: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.8178 - reconstruction_loss: 38.4554 - kl_loss: 5.3623 - lr: 5.0000e-04
# Epoch 105/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.8172 - reconstruction_loss: 38.4490 - kl_loss: 5.3682
# Epoch 00105: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.8178 - reconstruction_loss: 38.4498 - kl_loss: 5.3680 - lr: 5.0000e-04
# Epoch 106/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.8247 - reconstruction_loss: 38.4573 - kl_loss: 5.3674
# Epoch 00106: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.8294 - reconstruction_loss: 38.4619 - kl_loss: 5.3675 - lr: 5.0000e-04
# Epoch 107/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.7907 - reconstruction_loss: 38.4200 - kl_loss: 5.3707
# Epoch 00107: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.7919 - reconstruction_loss: 38.4208 - kl_loss: 5.3711 - lr: 5.0000e-04
# Epoch 108/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.7939 - reconstruction_loss: 38.4196 - kl_loss: 5.3743
# Epoch 00108: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.7929 - reconstruction_loss: 38.4187 - kl_loss: 5.3742 - lr: 5.0000e-04
# Epoch 109/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.7829 - reconstruction_loss: 38.4082 - kl_loss: 5.3747
# Epoch 00109: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.7760 - reconstruction_loss: 38.4018 - kl_loss: 5.3743 - lr: 5.0000e-04
# Epoch 110/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.7750 - reconstruction_loss: 38.4037 - kl_loss: 5.3713
# Epoch 00110: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.7809 - reconstruction_loss: 38.4098 - kl_loss: 5.3711 - lr: 5.0000e-04
# Epoch 111/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.7289 - reconstruction_loss: 38.3498 - kl_loss: 5.3791
# Epoch 00111: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.7313 - reconstruction_loss: 38.3518 - kl_loss: 5.3795 - lr: 5.0000e-04
# Epoch 112/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.7320 - reconstruction_loss: 38.3509 - kl_loss: 5.3811
# Epoch 00112: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.7333 - reconstruction_loss: 38.3525 - kl_loss: 5.3808 - lr: 5.0000e-04
# Epoch 113/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.7450 - reconstruction_loss: 38.3768 - kl_loss: 5.3682
# Epoch 00113: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.7388 - reconstruction_loss: 38.3705 - kl_loss: 5.3683 - lr: 5.0000e-04
# Epoch 114/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 43.6995 - reconstruction_loss: 38.3142 - kl_loss: 5.3853
# Epoch 00114: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.6924 - reconstruction_loss: 38.3070 - kl_loss: 5.3853 - lr: 5.0000e-04
# Epoch 115/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.7200 - reconstruction_loss: 38.3301 - kl_loss: 5.3899
# Epoch 00115: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.7204 - reconstruction_loss: 38.3305 - kl_loss: 5.3899 - lr: 5.0000e-04
# Epoch 116/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.7004 - reconstruction_loss: 38.3019 - kl_loss: 5.3984
# Epoch 00116: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.7011 - reconstruction_loss: 38.3027 - kl_loss: 5.3984 - lr: 5.0000e-04
# Epoch 117/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.7037 - reconstruction_loss: 38.3187 - kl_loss: 5.3850
# Epoch 00117: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.7062 - reconstruction_loss: 38.3212 - kl_loss: 5.3850 - lr: 5.0000e-04
# Epoch 118/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.6956 - reconstruction_loss: 38.3023 - kl_loss: 5.3933
# Epoch 00118: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.6953 - reconstruction_loss: 38.3017 - kl_loss: 5.3937 - lr: 5.0000e-04
# Epoch 119/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.6171 - reconstruction_loss: 38.2265 - kl_loss: 5.3906
# Epoch 00119: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.6181 - reconstruction_loss: 38.2274 - kl_loss: 5.3907 - lr: 5.0000e-04
# Epoch 120/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.6902 - reconstruction_loss: 38.2906 - kl_loss: 5.3996
# Epoch 00120: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.6923 - reconstruction_loss: 38.2927 - kl_loss: 5.3996 - lr: 5.0000e-04
# Epoch 121/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.6929 - reconstruction_loss: 38.2964 - kl_loss: 5.3965
# Epoch 00121: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.6866 - reconstruction_loss: 38.2899 - kl_loss: 5.3966 - lr: 5.0000e-04
# Epoch 122/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.6672 - reconstruction_loss: 38.2827 - kl_loss: 5.3845
# Epoch 00122: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.6693 - reconstruction_loss: 38.2848 - kl_loss: 5.3844 - lr: 5.0000e-04
# Epoch 123/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.5961 - reconstruction_loss: 38.2017 - kl_loss: 5.3944
# Epoch 00123: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.5976 - reconstruction_loss: 38.2032 - kl_loss: 5.3944 - lr: 5.0000e-04
# Epoch 124/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.6647 - reconstruction_loss: 38.2495 - kl_loss: 5.4153
# Epoch 00124: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.6658 - reconstruction_loss: 38.2505 - kl_loss: 5.4153 - lr: 5.0000e-04
# Epoch 125/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 43.5995 - reconstruction_loss: 38.2016 - kl_loss: 5.3979
# Epoch 00125: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.6005 - reconstruction_loss: 38.2029 - kl_loss: 5.3976 - lr: 5.0000e-04
# Epoch 126/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 43.5744 - reconstruction_loss: 38.1721 - kl_loss: 5.4023
# Epoch 00126: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.5728 - reconstruction_loss: 38.1703 - kl_loss: 5.4025 - lr: 5.0000e-04
# Epoch 127/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.6233 - reconstruction_loss: 38.2186 - kl_loss: 5.4047
# Epoch 00127: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.6205 - reconstruction_loss: 38.2157 - kl_loss: 5.4047 - lr: 5.0000e-04
# Epoch 128/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.5858 - reconstruction_loss: 38.1723 - kl_loss: 5.4135
# Epoch 00128: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.5836 - reconstruction_loss: 38.1700 - kl_loss: 5.4135 - lr: 5.0000e-04
# Epoch 129/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.5808 - reconstruction_loss: 38.1715 - kl_loss: 5.4093
# Epoch 00129: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.5857 - reconstruction_loss: 38.1765 - kl_loss: 5.4092 - lr: 5.0000e-04
# Epoch 130/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.5720 - reconstruction_loss: 38.1542 - kl_loss: 5.4178
# Epoch 00130: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.5780 - reconstruction_loss: 38.1602 - kl_loss: 5.4178 - lr: 5.0000e-04
# Epoch 131/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.5592 - reconstruction_loss: 38.1586 - kl_loss: 5.4006
# Epoch 00131: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.5577 - reconstruction_loss: 38.1572 - kl_loss: 5.4005 - lr: 5.0000e-04
# Epoch 132/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.5323 - reconstruction_loss: 38.1167 - kl_loss: 5.4156
# Epoch 00132: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.5305 - reconstruction_loss: 38.1143 - kl_loss: 5.4162 - lr: 5.0000e-04
# Epoch 133/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.5358 - reconstruction_loss: 38.1141 - kl_loss: 5.4216
# Epoch 00133: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.5479 - reconstruction_loss: 38.1263 - kl_loss: 5.4216 - lr: 5.0000e-04
# Epoch 134/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.5454 - reconstruction_loss: 38.1261 - kl_loss: 5.4193
# Epoch 00134: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.5408 - reconstruction_loss: 38.1218 - kl_loss: 5.4191 - lr: 5.0000e-04
# Epoch 135/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.5328 - reconstruction_loss: 38.1152 - kl_loss: 5.4175
# Epoch 00135: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.5386 - reconstruction_loss: 38.1208 - kl_loss: 5.4178 - lr: 5.0000e-04
# Epoch 136/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.5253 - reconstruction_loss: 38.1225 - kl_loss: 5.4028
# Epoch 00136: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.5243 - reconstruction_loss: 38.1214 - kl_loss: 5.4029 - lr: 5.0000e-04
# Epoch 137/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.5023 - reconstruction_loss: 38.0729 - kl_loss: 5.4294
# Epoch 00137: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.5055 - reconstruction_loss: 38.0763 - kl_loss: 5.4292 - lr: 5.0000e-04
# Epoch 138/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.5069 - reconstruction_loss: 38.0766 - kl_loss: 5.4302
# Epoch 00138: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.5089 - reconstruction_loss: 38.0788 - kl_loss: 5.4301 - lr: 5.0000e-04
# Epoch 139/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.4693 - reconstruction_loss: 38.0458 - kl_loss: 5.4235
# Epoch 00139: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.4723 - reconstruction_loss: 38.0488 - kl_loss: 5.4235 - lr: 5.0000e-04
# Epoch 140/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.4955 - reconstruction_loss: 38.0611 - kl_loss: 5.4343
# Epoch 00140: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 43.4847 - reconstruction_loss: 38.0503 - kl_loss: 5.4344 - lr: 5.0000e-04
# Epoch 141/200
# ...
# Epoch 00154: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3941 - reconstruction_loss: 37.9555 - kl_loss: 5.4387 - lr: 5.0000e-04
# Epoch 155/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.4048 - reconstruction_loss: 37.9491 - kl_loss: 5.4557
# Epoch 00155: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.4075 - reconstruction_loss: 37.9516 - kl_loss: 5.4559 - lr: 5.0000e-04
# Epoch 156/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.4027 - reconstruction_loss: 37.9553 - kl_loss: 5.4473
# Epoch 00156: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.4035 - reconstruction_loss: 37.9562 - kl_loss: 5.4473 - lr: 5.0000e-04
# Epoch 157/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.3911 - reconstruction_loss: 37.9354 - kl_loss: 5.4557
# Epoch 00157: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3894 - reconstruction_loss: 37.9341 - kl_loss: 5.4554 - lr: 5.0000e-04
# Epoch 158/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.3563 - reconstruction_loss: 37.9015 - kl_loss: 5.4549
# Epoch 00158: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3595 - reconstruction_loss: 37.9044 - kl_loss: 5.4552 - lr: 5.0000e-04
# Epoch 159/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.3041 - reconstruction_loss: 37.8636 - kl_loss: 5.4405
# Epoch 00159: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3027 - reconstruction_loss: 37.8622 - kl_loss: 5.4404 - lr: 5.0000e-04
# Epoch 160/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.3652 - reconstruction_loss: 37.9026 - kl_loss: 5.4626
# Epoch 00160: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3647 - reconstruction_loss: 37.9023 - kl_loss: 5.4624 - lr: 5.0000e-04
# Epoch 161/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.3565 - reconstruction_loss: 37.8943 - kl_loss: 5.4622
# Epoch 00161: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3550 - reconstruction_loss: 37.8931 - kl_loss: 5.4620 - lr: 5.0000e-04
# Epoch 162/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.3779 - reconstruction_loss: 37.9198 - kl_loss: 5.4580
# Epoch 00162: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3785 - reconstruction_loss: 37.9205 - kl_loss: 5.4580 - lr: 5.0000e-04
# Epoch 163/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.3398 - reconstruction_loss: 37.8782 - kl_loss: 5.4617
# Epoch 00163: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3425 - reconstruction_loss: 37.8807 - kl_loss: 5.4617 - lr: 5.0000e-04
# Epoch 164/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.3248 - reconstruction_loss: 37.8610 - kl_loss: 5.4638
# Epoch 00164: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3223 - reconstruction_loss: 37.8588 - kl_loss: 5.4635 - lr: 5.0000e-04
# Epoch 165/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.3305 - reconstruction_loss: 37.8669 - kl_loss: 5.4636
# Epoch 00165: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3264 - reconstruction_loss: 37.8629 - kl_loss: 5.4635 - lr: 5.0000e-04
# Epoch 166/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.3474 - reconstruction_loss: 37.8861 - kl_loss: 5.4613
# Epoch 00166: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3488 - reconstruction_loss: 37.8876 - kl_loss: 5.4612 - lr: 5.0000e-04
# Epoch 167/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.2881 - reconstruction_loss: 37.8312 - kl_loss: 5.4568
# Epoch 00167: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2817 - reconstruction_loss: 37.8243 - kl_loss: 5.4574 - lr: 5.0000e-04
# Epoch 168/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.3317 - reconstruction_loss: 37.8624 - kl_loss: 5.4693
# Epoch 00168: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3332 - reconstruction_loss: 37.8639 - kl_loss: 5.4694 - lr: 5.0000e-04
# Epoch 169/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.3272 - reconstruction_loss: 37.8638 - kl_loss: 5.4634
# Epoch 00169: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3275 - reconstruction_loss: 37.8640 - kl_loss: 5.4635 - lr: 5.0000e-04
# Epoch 170/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.2513 - reconstruction_loss: 37.7899 - kl_loss: 5.4614
# Epoch 00170: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2546 - reconstruction_loss: 37.7933 - kl_loss: 5.4613 - lr: 5.0000e-04
# Epoch 171/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.3091 - reconstruction_loss: 37.8351 - kl_loss: 5.4741
# Epoch 00171: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3098 - reconstruction_loss: 37.8356 - kl_loss: 5.4741 - lr: 5.0000e-04
# Epoch 172/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 43.3203 - reconstruction_loss: 37.8548 - kl_loss: 5.4655
# Epoch 00172: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.3159 - reconstruction_loss: 37.8505 - kl_loss: 5.4654 - lr: 5.0000e-04
# Epoch 173/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.2865 - reconstruction_loss: 37.8188 - kl_loss: 5.4678
# Epoch 00173: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2771 - reconstruction_loss: 37.8096 - kl_loss: 5.4676 - lr: 5.0000e-04
# Epoch 174/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.2660 - reconstruction_loss: 37.8010 - kl_loss: 5.4650
# Epoch 00174: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2612 - reconstruction_loss: 37.7962 - kl_loss: 5.4650 - lr: 5.0000e-04
# Epoch 175/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.2630 - reconstruction_loss: 37.7879 - kl_loss: 5.4752
# Epoch 00175: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2629 - reconstruction_loss: 37.7878 - kl_loss: 5.4751 - lr: 5.0000e-04
# Epoch 176/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.2486 - reconstruction_loss: 37.7824 - kl_loss: 5.4663
# Epoch 00176: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2505 - reconstruction_loss: 37.7841 - kl_loss: 5.4664 - lr: 5.0000e-04
# Epoch 177/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.2528 - reconstruction_loss: 37.7842 - kl_loss: 5.4686
# Epoch 00177: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2508 - reconstruction_loss: 37.7821 - kl_loss: 5.4687 - lr: 5.0000e-04
# Epoch 178/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.2487 - reconstruction_loss: 37.7796 - kl_loss: 5.4690
# Epoch 00178: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2532 - reconstruction_loss: 37.7839 - kl_loss: 5.4693 - lr: 5.0000e-04
# Epoch 179/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.2291 - reconstruction_loss: 37.7567 - kl_loss: 5.4724
# Epoch 00179: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2309 - reconstruction_loss: 37.7583 - kl_loss: 5.4726 - lr: 5.0000e-04
# Epoch 180/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.2533 - reconstruction_loss: 37.7802 - kl_loss: 5.4731
# Epoch 00180: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2529 - reconstruction_loss: 37.7798 - kl_loss: 5.4730 - lr: 5.0000e-04
# Epoch 181/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.2215 - reconstruction_loss: 37.7503 - kl_loss: 5.4712
# Epoch 00181: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2225 - reconstruction_loss: 37.7514 - kl_loss: 5.4712 - lr: 5.0000e-04
# Epoch 182/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 43.2558 - reconstruction_loss: 37.7759 - kl_loss: 5.4799
# Epoch 00182: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2559 - reconstruction_loss: 37.7759 - kl_loss: 5.4800 - lr: 5.0000e-04
# Epoch 183/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.2098 - reconstruction_loss: 37.7216 - kl_loss: 5.4882
# Epoch 00183: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2100 - reconstruction_loss: 37.7219 - kl_loss: 5.4881 - lr: 5.0000e-04
# Epoch 184/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.2086 - reconstruction_loss: 37.7304 - kl_loss: 5.4782
# Epoch 00184: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2074 - reconstruction_loss: 37.7293 - kl_loss: 5.4781 - lr: 5.0000e-04
# Epoch 185/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.2042 - reconstruction_loss: 37.7211 - kl_loss: 5.4831
# Epoch 00185: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2082 - reconstruction_loss: 37.7251 - kl_loss: 5.4831 - lr: 5.0000e-04
# Epoch 186/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.2123 - reconstruction_loss: 37.7191 - kl_loss: 5.4932
# Epoch 00186: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2133 - reconstruction_loss: 37.7202 - kl_loss: 5.4931 - lr: 5.0000e-04
# Epoch 187/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.2007 - reconstruction_loss: 37.7169 - kl_loss: 5.4838
# Epoch 00187: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2026 - reconstruction_loss: 37.7188 - kl_loss: 5.4838 - lr: 5.0000e-04
# Epoch 188/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.1905 - reconstruction_loss: 37.7029 - kl_loss: 5.4876
# Epoch 00188: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1918 - reconstruction_loss: 37.7040 - kl_loss: 5.4879 - lr: 5.0000e-04
# Epoch 189/200
# 1873/1875 [============================>.] - ETA: 0s - loss: 43.2017 - reconstruction_loss: 37.7151 - kl_loss: 5.4866
# Epoch 00189: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.2085 - reconstruction_loss: 37.7224 - kl_loss: 5.4862 - lr: 5.0000e-04
# Epoch 190/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.1645 - reconstruction_loss: 37.6877 - kl_loss: 5.4767
# Epoch 00190: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1659 - reconstruction_loss: 37.6889 - kl_loss: 5.4770 - lr: 5.0000e-04
# Epoch 191/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.1491 - reconstruction_loss: 37.6509 - kl_loss: 5.4982
# Epoch 00191: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1473 - reconstruction_loss: 37.6491 - kl_loss: 5.4982 - lr: 5.0000e-04
# Epoch 192/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.1607 - reconstruction_loss: 37.6764 - kl_loss: 5.4843
# Epoch 00192: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1602 - reconstruction_loss: 37.6759 - kl_loss: 5.4843 - lr: 5.0000e-04
# Epoch 193/200
# 1875/1875 [==============================] - ETA: 0s - loss: 43.1407 - reconstruction_loss: 37.6503 - kl_loss: 5.4904
# Epoch 00193: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1401 - reconstruction_loss: 37.6498 - kl_loss: 5.4904 - lr: 5.0000e-04
# Epoch 194/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.1915 - reconstruction_loss: 37.7022 - kl_loss: 5.4893
# Epoch 00194: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1927 - reconstruction_loss: 37.7037 - kl_loss: 5.4890 - lr: 5.0000e-04
# Epoch 195/200
# 1874/1875 [============================>.] - ETA: 0s - loss: 43.1387 - reconstruction_loss: 37.6482 - kl_loss: 5.4905
# Epoch 00195: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1430 - reconstruction_loss: 37.6527 - kl_loss: 5.4903 - lr: 5.0000e-04
# Epoch 196/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.1714 - reconstruction_loss: 37.6821 - kl_loss: 5.4892
# Epoch 00196: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1698 - reconstruction_loss: 37.6809 - kl_loss: 5.4889 - lr: 5.0000e-04
# Epoch 197/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.1620 - reconstruction_loss: 37.6629 - kl_loss: 5.4992
# Epoch 00197: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1636 - reconstruction_loss: 37.6643 - kl_loss: 5.4993 - lr: 5.0000e-04
# Epoch 198/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.1530 - reconstruction_loss: 37.6609 - kl_loss: 5.4921
# Epoch 00198: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1562 - reconstruction_loss: 37.6639 - kl_loss: 5.4924 - lr: 5.0000e-04
# Epoch 199/200
# 1872/1875 [============================>.] - ETA: 0s - loss: 43.1157 - reconstruction_loss: 37.6228 - kl_loss: 5.4928
# Epoch 00199: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1174 - reconstruction_loss: 37.6245 - kl_loss: 5.4929 - lr: 5.0000e-04
# Epoch 200/200
# 1871/1875 [============================>.] - ETA: 0s - loss: 43.1567 - reconstruction_loss: 37.6664 - kl_loss: 5.4903
# Epoch 00200: saving model to run/vae/0002_digits/weights/weights.h5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 43.1560 - reconstruction_loss: 37.6659 - kl_loss: 5.4902 - lr: 5.0000e-04

# %%
vae = load_model(VariationalAutoencoder, RUN_FOLDER)

# %%
#reconstructing original paintings

n_to_show = 10
example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]

_,_,z_points = vae.encoder.predict(example_images)

reconst_images = vae.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+1)
    sub.axis('off')
    sub.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=sub.transAxes)
            
    sub.imshow(img, cmap='gray_r')

for i in range(n_to_show):
    img = reconst_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    sub.axis('off')
    sub.imshow(img, cmap='gray_r')

# %%
#Encoders space
n_to_show = 5000
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

_,_,z_points = vae.encoder.predict(example_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)
plt.show()

# %%
#Newly generated digits
figsize = 8
plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)


grid_size = 15
grid_depth = 2
figsize = 15

x = np.random.normal(size = grid_size * grid_depth)
y = np.random.normal(size = grid_size * grid_depth)

z_grid = np.array(list(zip(x, y)))
reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()

fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=8, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')

# %%
n_to_show = 5000
grid_size = 15
fig_height = 7
fig_width = 15

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

_,_,z_points = vae.encoder.predict(example_images)
p_points = norm.cdf(z_points)

fig = plt.figure(figsize=(fig_width, fig_height))

ax = fig.add_subplot(1, 2, 1)
plot_1 = ax.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar(plot_1)

ax = fig.add_subplot(1, 2, 2)
plot_2 = ax.scatter(p_points[:, 0] , p_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=5)



plt.show()

# %%
n_to_show = 5000
grid_size = 20
figsize = 8

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

_,_,z_points = vae.encoder.predict(example_images)

plt.figure(figsize=(5, 5))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()

x = norm.ppf(np.linspace(0.01, 0.99, grid_size))
y = norm.ppf(np.linspace(0.01, 0.99, grid_size))
xv, yv = np.meshgrid(x, y)
xv = xv.flatten()
yv = yv.flatten()
z_grid = np.array(list(zip(xv, yv)))

reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'black'#, cmap='rainbow' , c= example_labels
            , alpha=1, s=2)




plt.show()


fig = plt.figure(figsize=(figsize, figsize))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(grid_size**2):
    ax = fig.add_subplot(grid_size, grid_size, i+1)
    ax.axis('off')
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
