# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaym416/GAN/blob/main/Generative_deep_learning_Encoder_Decoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##utils-> callbacks

from tensorflow.keras.callbacks import Callback, LearningRateScheduler
import numpy as np
import matplotlib.pyplot as plt
import os

#### CALLBACKS
class CustomCallback(Callback):
    
    def __init__(self, run_folder, print_every_n_batches, initial_epoch, vae):
        self.epoch = initial_epoch
        self.run_folder = run_folder
        self.print_every_n_batches = print_every_n_batches
        self.vae = vae

    def on_batch_end(self, batch, logs={}):  
        if batch % self.print_every_n_batches == 0:
            z_new = np.random.normal(size = (1,self.vae.z_dim))
            reconst = self.vae.decoder.predict(np.array(z_new))[0].squeeze()

            filepath = os.path.join(self.run_folder, 'images', 'img_' + str(self.epoch).zfill(3) + '_' + str(batch) + '.jpg')
            if len(reconst.shape) == 2:
                plt.imsave(filepath, reconst, cmap='gray_r')
            else:
                plt.imsave(filepath, reconst)

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch += 1



def step_decay_schedule(initial_lr, decay_factor=0.5, step_size=1):
    '''
    Wrapper function to create a LearningRateScheduler with step decay schedule.
    '''
    def schedule(epoch):
        new_lr = initial_lr * (decay_factor ** np.floor(epoch/step_size))
        
        return new_lr

    return LearningRateScheduler(schedule)

# %%
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import LeakyReLU
import tensorflow.keras.backend as K
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import Activation,Reshape
import numpy as np
import os
import pickle
from tensorflow.keras.callbacks import ModelCheckpoint 
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

class Autoencoder():
    def __init__(self
        , input_dim
        , encoder_conv_filters
        , encoder_conv_kernel_size
        , encoder_conv_strides
        , decoder_conv_t_filters
        , decoder_conv_t_kernel_size
        , decoder_conv_t_strides
        , z_dim
        , use_batch_norm = False
        , use_dropout = False
        ):

        self.name = 'autoencoder'

        self.input_dim = input_dim
        self.encoder_conv_filters = encoder_conv_filters
        self.encoder_conv_kernel_size = encoder_conv_kernel_size
        self.encoder_conv_strides = encoder_conv_strides
        self.decoder_conv_t_filters = decoder_conv_t_filters
        self.decoder_conv_t_kernel_size = decoder_conv_t_kernel_size
        self.decoder_conv_t_strides = decoder_conv_t_strides
        self.z_dim = z_dim

        self.use_batch_norm = use_batch_norm
        self.use_dropout = use_dropout

        self.n_layers_encoder = len(encoder_conv_filters)
        self.n_layers_decoder = len(decoder_conv_t_filters)

        self._build()

    def _build(self):

        ### THE ENCODER
        encoder_input = Input(shape=self.input_dim, name='encoder_input')

        x = encoder_input

        for i in range(self.n_layers_encoder):
            conv_layer = Conv2D(
                filters = self.encoder_conv_filters[i]
                , kernel_size = self.encoder_conv_kernel_size[i]
                , strides = self.encoder_conv_strides[i]
                , padding = 'same'
                , name = 'encoder_conv_' + str(i)
                )

            x = conv_layer(x)

            x = LeakyReLU()(x)

            if self.use_batch_norm:
                x = BatchNormalization()(x)

            if self.use_dropout:
                x = Dropout(rate = 0.25)(x)

        shape_before_flattening = K.int_shape(x)[1:]

        x = Flatten()(x)
        encoder_output= Dense(self.z_dim, name='encoder_output')(x)

        self.encoder = Model(encoder_input, encoder_output)


        ### THE DECODER
        decoder_input = Input(shape=(self.z_dim,), name='decoder_input')

        x = Dense(np.prod(shape_before_flattening))(decoder_input)
        x = Reshape(shape_before_flattening)(x)

        for i in range(self.n_layers_decoder):
            conv_t_layer = Conv2DTranspose(
                filters = self.decoder_conv_t_filters[i]
                , kernel_size = self.decoder_conv_t_kernel_size[i]
                , strides = self.decoder_conv_t_strides[i]
                , padding = 'same'
                , name = 'decoder_conv_t_' + str(i)
                )

            x = conv_t_layer(x)

            if i < self.n_layers_decoder - 1:
                x = LeakyReLU()(x)
                
                if self.use_batch_norm:
                    x = BatchNormalization()(x)
                
                if self.use_dropout:
                    x = Dropout(rate = 0.25)(x)
            else:
                x = Activation('sigmoid')(x)

        decoder_output = x

        self.decoder = Model(decoder_input, decoder_output)

        ### THE FULL AUTOENCODER
        model_input = encoder_input
        model_output = self.decoder(encoder_output)

        self.model = Model(model_input, model_output)


    def compile(self, learning_rate):
        self.learning_rate = learning_rate

        optimizer = Adam(lr=learning_rate)

        def r_loss(y_true, y_pred):
            return K.mean(K.square(y_true - y_pred), axis = [1,2,3])

        self.model.compile(optimizer=optimizer, loss = r_loss)

    def save(self, folder):

        if not os.path.exists(folder):
            os.makedirs(folder)
            os.makedirs(os.path.join(folder, 'viz'))
            os.makedirs(os.path.join(folder, 'weights'))
            os.makedirs(os.path.join(folder, 'images'))

        with open(os.path.join(folder, 'params.pkl'), 'wb') as f:
            pickle.dump([
                self.input_dim
                , self.encoder_conv_filters
                , self.encoder_conv_kernel_size
                , self.encoder_conv_strides
                , self.decoder_conv_t_filters
                , self.decoder_conv_t_kernel_size
                , self.decoder_conv_t_strides
                , self.z_dim
                , self.use_batch_norm
                , self.use_dropout
                ], f)

        self.plot_model(folder)

        


    def load_weights(self, filepath):
        self.model.load_weights(filepath)

    
    def train(self, x_train, batch_size, epochs, run_folder, print_every_n_batches = 100, initial_epoch = 0, lr_decay = 1):

        custom_callback = CustomCallback(run_folder, print_every_n_batches, initial_epoch, self)
        lr_sched = step_decay_schedule(initial_lr=self.learning_rate, decay_factor=lr_decay, step_size=1)

        checkpoint2 = ModelCheckpoint(os.path.join(run_folder, 'weights/weights.h5'), save_weights_only = True, verbose=1)

        callbacks_list = [checkpoint2, custom_callback, lr_sched]

        self.model.fit(     
            x_train
            , x_train
            , batch_size = batch_size
            , shuffle = True
            , epochs = epochs
            , initial_epoch = initial_epoch
            , callbacks = callbacks_list
        )

    def plot_model(self, run_folder):
        plot_model(self.model, to_file=os.path.join(run_folder ,'viz/model.png'), show_shapes = True, show_layer_names = True)
        plot_model(self.encoder, to_file=os.path.join(run_folder ,'viz/encoder.png'), show_shapes = True, show_layer_names = True)
        plot_model(self.decoder, to_file=os.path.join(run_folder ,'viz/decoder.png'), show_shapes = True, show_layer_names = True)

# %%
def load_mnist():
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    x_train = x_train.astype('float32') / 255.
    x_train = x_train.reshape(x_train.shape + (1,))
    x_test = x_test.astype('float32') / 255.
    x_test = x_test.reshape(x_test.shape + (1,))

    return (x_train, y_train), (x_test, y_test)
(x_train, y_train), (x_test, y_test) = load_mnist()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# run params
SECTION = 'vae'
RUN_ID = '0001'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

os.makedirs(RUN_FOLDER,exist_ok=True)
os.makedirs(os.path.join(RUN_FOLDER, 'viz'),exist_ok=True)
os.makedirs(os.path.join(RUN_FOLDER, 'images'),exist_ok=True)
os.makedirs(os.path.join(RUN_FOLDER, 'weights'),exist_ok=True)

MODE =  'build' #'load' #

# %%
AE = Autoencoder(
input_dim = (28,28,1)
, encoder_conv_filters = [32,64,64, 64]
, encoder_conv_kernel_size = [3,3,3,3]
, encoder_conv_strides = [1,2,2,1]
, decoder_conv_t_filters = [64,64,32,1]
, decoder_conv_t_kernel_size = [3,3,3,3]
, decoder_conv_t_strides = [1,2,2,1]
, z_dim = 2)

# %%
if MODE == 'build':
    AE.save(RUN_FOLDER)
else:
    AE.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
AE.encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 28, 28, 1)]       0
#
#  encoder_conv_0 (Conv2D)     (None, 28, 28, 32)        320
#
#  leaky_re_lu (LeakyReLU)     (None, 28, 28, 32)        0
#
#  encoder_conv_1 (Conv2D)     (None, 14, 14, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  encoder_conv_2 (Conv2D)     (None, 7, 7, 64)          36928
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  encoder_conv_3 (Conv2D)     (None, 7, 7, 64)          36928
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  encoder_output (Dense)      (None, 2)                 6274
#
# =================================================================
# Total params: 98,946
# Trainable params: 98,946
# Non-trainable params: 0
# _________________________________________________________________

# %%
AE.decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 2)]               0
#
#  dense (Dense)               (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  decoder_conv_t_0 (Conv2DTra  (None, 7, 7, 64)         36928
#  nspose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  decoder_conv_t_1 (Conv2DTra  (None, 14, 14, 64)       36928
#  nspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  decoder_conv_t_2 (Conv2DTra  (None, 28, 28, 32)       18464
#  nspose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 28, 28, 32)        0
#
#  decoder_conv_t_3 (Conv2DTra  (None, 28, 28, 1)        289
#  nspose)
#
#  activation (Activation)     (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
LEARNING_RATE = 0.0005
BATCH_SIZE = 32
INITIAL_EPOCH =0

# %%
AE.compile(LEARNING_RATE)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
tf.config.run_functions_eagerly(True)
AE.train(     
    x_train[:1000]
    , batch_size = BATCH_SIZE
    , epochs = 200
    , run_folder = RUN_FOLDER
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4527: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# Epoch 1/200
# 32/32 [==============================] - ETA: 0s - loss: 0.1819
# Epoch 00001: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 31s 46ms/step - loss: 0.1819 - lr: 5.0000e-04
# Epoch 2/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0923
# Epoch 00002: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0923 - lr: 5.0000e-04
# Epoch 3/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0693
# Epoch 00003: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0693 - lr: 5.0000e-04
# Epoch 4/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0637
# Epoch 00004: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0637 - lr: 5.0000e-04
# Epoch 5/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0590
# Epoch 00005: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0590 - lr: 5.0000e-04
# Epoch 6/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0570
# Epoch 00006: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0570 - lr: 5.0000e-04
# Epoch 7/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0557
# Epoch 00007: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0557 - lr: 5.0000e-04
# Epoch 8/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0547
# Epoch 00008: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0547 - lr: 5.0000e-04
# Epoch 9/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0540
# Epoch 00009: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0540 - lr: 5.0000e-04
# Epoch 10/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0534
# Epoch 00010: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0534 - lr: 5.0000e-04
# Epoch 11/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0529
# Epoch 00011: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0529 - lr: 5.0000e-04
# Epoch 12/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0523
# Epoch 00012: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0523 - lr: 5.0000e-04
# Epoch 13/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0519
# Epoch 00013: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0519 - lr: 5.0000e-04
# Epoch 14/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0517
# Epoch 00014: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0516 - lr: 5.0000e-04
# Epoch 15/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0512
# Epoch 00015: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0512 - lr: 5.0000e-04
# Epoch 16/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0508
# Epoch 00016: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0508 - lr: 5.0000e-04
# Epoch 17/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0506
# Epoch 00017: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0506 - lr: 5.0000e-04
# Epoch 18/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0501
# Epoch 00018: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0501 - lr: 5.0000e-04
# Epoch 19/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0499
# Epoch 00019: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0499 - lr: 5.0000e-04
# Epoch 20/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0496
# Epoch 00020: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0496 - lr: 5.0000e-04
# Epoch 21/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0495
# Epoch 00021: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0494 - lr: 5.0000e-04
# Epoch 22/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0492
# Epoch 00022: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0492 - lr: 5.0000e-04
# Epoch 23/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0491
# Epoch 00023: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0491 - lr: 5.0000e-04
# Epoch 24/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0488
# Epoch 00024: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0488 - lr: 5.0000e-04
# Epoch 25/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0484
# Epoch 00025: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0485 - lr: 5.0000e-04
# Epoch 26/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0483
# Epoch 00026: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0483 - lr: 5.0000e-04
# Epoch 27/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0481
# Epoch 00027: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0481 - lr: 5.0000e-04
# Epoch 28/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0478
# Epoch 00028: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0478 - lr: 5.0000e-04
# Epoch 29/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0478
# Epoch 00029: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0478 - lr: 5.0000e-04
# Epoch 30/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0475
# Epoch 00030: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0475 - lr: 5.0000e-04
# Epoch 31/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0472
# Epoch 00031: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0472 - lr: 5.0000e-04
# Epoch 32/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0473
# Epoch 00032: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0473 - lr: 5.0000e-04
# Epoch 33/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0470
# Epoch 00033: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0469 - lr: 5.0000e-04
# Epoch 34/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0468
# Epoch 00034: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0467 - lr: 5.0000e-04
# Epoch 35/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0466
# Epoch 00035: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0466 - lr: 5.0000e-04
# Epoch 36/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0461
# Epoch 00036: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0461 - lr: 5.0000e-04
# Epoch 37/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0460
# Epoch 00037: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0461 - lr: 5.0000e-04
# Epoch 38/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0459
# Epoch 00038: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0459 - lr: 5.0000e-04
# Epoch 39/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0458
# Epoch 00039: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0458 - lr: 5.0000e-04
# Epoch 40/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0456
# Epoch 00040: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0456 - lr: 5.0000e-04
# Epoch 41/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0456
# Epoch 00041: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0456 - lr: 5.0000e-04
# Epoch 42/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0453
# Epoch 00042: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0453 - lr: 5.0000e-04
# Epoch 43/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0452
# Epoch 00043: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0452 - lr: 5.0000e-04
# Epoch 44/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0450
# Epoch 00044: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0451 - lr: 5.0000e-04
# Epoch 45/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0447
# Epoch 00045: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0447 - lr: 5.0000e-04
# Epoch 46/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 00046: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0446 - lr: 5.0000e-04
# Epoch 47/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 00047: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0446 - lr: 5.0000e-04
# Epoch 48/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0442
# Epoch 00048: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0442 - lr: 5.0000e-04
# Epoch 49/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 00049: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0446 - lr: 5.0000e-04
# Epoch 50/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0440
# Epoch 00050: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0440 - lr: 5.0000e-04
# Epoch 51/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0438
# Epoch 00051: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0438 - lr: 5.0000e-04
# Epoch 52/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0438
# Epoch 00052: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0438 - lr: 5.0000e-04
# Epoch 53/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0437
# Epoch 00053: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0437 - lr: 5.0000e-04
# Epoch 54/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0437
# Epoch 00054: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0437 - lr: 5.0000e-04
# Epoch 55/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0432
# Epoch 00055: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0432 - lr: 5.0000e-04
# Epoch 56/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0431
# Epoch 00056: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0430 - lr: 5.0000e-04
# Epoch 57/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0431
# Epoch 00057: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0430 - lr: 5.0000e-04
# Epoch 58/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0426
# Epoch 00058: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0427 - lr: 5.0000e-04
# Epoch 59/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0427
# Epoch 00059: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0427 - lr: 5.0000e-04
# Epoch 60/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0428
# Epoch 00060: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0428 - lr: 5.0000e-04
# Epoch 61/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0424
# Epoch 00061: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0424 - lr: 5.0000e-04
# Epoch 62/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0424
# Epoch 00062: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0424 - lr: 5.0000e-04
# Epoch 63/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0422
# Epoch 00063: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0422 - lr: 5.0000e-04
# Epoch 64/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0419
# Epoch 00064: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0419 - lr: 5.0000e-04
# Epoch 65/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0418
# Epoch 00065: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0418 - lr: 5.0000e-04
# Epoch 66/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0420
# Epoch 00066: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0420 - lr: 5.0000e-04
# Epoch 67/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0419
# Epoch 00067: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0419 - lr: 5.0000e-04
# Epoch 68/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0418
# Epoch 00068: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0418 - lr: 5.0000e-04
# Epoch 69/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0415
# Epoch 00069: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0415 - lr: 5.0000e-04
# Epoch 70/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0417
# Epoch 00070: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0417 - lr: 5.0000e-04
# Epoch 71/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0415
# Epoch 00071: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0415 - lr: 5.0000e-04
# Epoch 72/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0411
# Epoch 00072: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0411 - lr: 5.0000e-04
# Epoch 73/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0408
# Epoch 00073: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0409 - lr: 5.0000e-04
# Epoch 74/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0410
# Epoch 00074: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0410 - lr: 5.0000e-04
# Epoch 75/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0410
# Epoch 00075: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0410 - lr: 5.0000e-04
# Epoch 76/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0407
# Epoch 00076: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0409 - lr: 5.0000e-04
# Epoch 77/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0408
# Epoch 00077: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0407 - lr: 5.0000e-04
# Epoch 78/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0406
# Epoch 00078: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0406 - lr: 5.0000e-04
# Epoch 79/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0402
# Epoch 00079: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0402 - lr: 5.0000e-04
# Epoch 80/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0400
# Epoch 00080: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0400 - lr: 5.0000e-04
# Epoch 81/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0400
# Epoch 00081: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0400 - lr: 5.0000e-04
# Epoch 82/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0400
# Epoch 00082: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0400 - lr: 5.0000e-04
# Epoch 83/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0398
# Epoch 00083: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0398 - lr: 5.0000e-04
# Epoch 84/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0398
# Epoch 00084: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0398 - lr: 5.0000e-04
# Epoch 85/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0398
# Epoch 00085: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0398 - lr: 5.0000e-04
# Epoch 86/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0399
# Epoch 00086: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0399 - lr: 5.0000e-04
# Epoch 87/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0396
# Epoch 00087: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0397 - lr: 5.0000e-04
# Epoch 88/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0396
# Epoch 00088: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0396 - lr: 5.0000e-04
# Epoch 89/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0395
# Epoch 00089: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0394 - lr: 5.0000e-04
# Epoch 90/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0394
# Epoch 00090: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0394 - lr: 5.0000e-04
# Epoch 91/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0394
# Epoch 00091: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0394 - lr: 5.0000e-04
# Epoch 92/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0393
# Epoch 00092: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0393 - lr: 5.0000e-04
# Epoch 93/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0393
# Epoch 00093: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0393 - lr: 5.0000e-04
# Epoch 94/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0388
# Epoch 00094: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0389 - lr: 5.0000e-04
# Epoch 95/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0388
# Epoch 00095: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0388 - lr: 5.0000e-04
# Epoch 96/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0390
# Epoch 00096: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0390 - lr: 5.0000e-04
# Epoch 97/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0388
# Epoch 00097: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0388 - lr: 5.0000e-04
# Epoch 98/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0387
# Epoch 00098: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0387 - lr: 5.0000e-04
# Epoch 99/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0386
# Epoch 00099: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0385 - lr: 5.0000e-04
# Epoch 100/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0389
# Epoch 00100: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0389 - lr: 5.0000e-04
# Epoch 101/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0391
# Epoch 00101: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0391 - lr: 5.0000e-04
# Epoch 102/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0387
# Epoch 00102: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0387 - lr: 5.0000e-04
# Epoch 103/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0388
# Epoch 00103: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0389 - lr: 5.0000e-04
# Epoch 104/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0387
# Epoch 00104: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0387 - lr: 5.0000e-04
# Epoch 105/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0382
# Epoch 00105: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0381 - lr: 5.0000e-04
# Epoch 106/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 00106: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0383 - lr: 5.0000e-04
# Epoch 107/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0384
# Epoch 00107: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0384 - lr: 5.0000e-04
# Epoch 108/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0382
# Epoch 00108: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0382 - lr: 5.0000e-04
# Epoch 109/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0378
# Epoch 00109: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0378 - lr: 5.0000e-04
# Epoch 110/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0381
# Epoch 00110: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0381 - lr: 5.0000e-04
# Epoch 111/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0378
# Epoch 00111: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0378 - lr: 5.0000e-04
# Epoch 112/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0380
# Epoch 00112: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0380 - lr: 5.0000e-04
# Epoch 113/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0380
# Epoch 00113: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0380 - lr: 5.0000e-04
# Epoch 114/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00114: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0378 - lr: 5.0000e-04
# Epoch 115/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0378
# Epoch 00115: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0378 - lr: 5.0000e-04
# Epoch 116/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0377
# Epoch 00116: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0377 - lr: 5.0000e-04
# Epoch 117/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0376
# Epoch 00117: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0376 - lr: 5.0000e-04
# Epoch 118/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0378
# Epoch 00118: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0378 - lr: 5.0000e-04
# Epoch 119/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00119: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0378 - lr: 5.0000e-04
# Epoch 120/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0379
# Epoch 00120: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0379 - lr: 5.0000e-04
# Epoch 121/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00121: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0376 - lr: 5.0000e-04
# Epoch 122/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00122: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0377 - lr: 5.0000e-04
# Epoch 123/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0373
# Epoch 00123: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0373 - lr: 5.0000e-04
# Epoch 124/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0374
# Epoch 00124: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0374 - lr: 5.0000e-04
# Epoch 125/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0372
# Epoch 00125: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0372 - lr: 5.0000e-04
# Epoch 126/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0374
# Epoch 00126: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0374 - lr: 5.0000e-04
# Epoch 127/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0373
# Epoch 00127: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0374 - lr: 5.0000e-04
# Epoch 128/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0374
# Epoch 00128: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0374 - lr: 5.0000e-04
# Epoch 129/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00129: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0377 - lr: 5.0000e-04
# Epoch 130/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0375
# Epoch 00130: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0375 - lr: 5.0000e-04
# Epoch 131/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0372
# Epoch 00131: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0372 - lr: 5.0000e-04
# Epoch 132/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0372
# Epoch 00132: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0371 - lr: 5.0000e-04
# Epoch 133/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0370
# Epoch 00133: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0370 - lr: 5.0000e-04
# Epoch 134/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0369
# Epoch 00134: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0369 - lr: 5.0000e-04
# Epoch 135/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0369
# Epoch 00135: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0369 - lr: 5.0000e-04
# Epoch 136/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0371
# Epoch 00136: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0371 - lr: 5.0000e-04
# Epoch 137/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0367
# Epoch 00137: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0367 - lr: 5.0000e-04
# Epoch 138/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0365
# Epoch 00138: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0365 - lr: 5.0000e-04
# Epoch 139/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0366
# Epoch 00139: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0366 - lr: 5.0000e-04
# Epoch 140/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0365
# Epoch 00140: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0365 - lr: 5.0000e-04
# Epoch 141/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 00141: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0369 - lr: 5.0000e-04
# Epoch 142/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0367
# Epoch 00142: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0367 - lr: 5.0000e-04
# Epoch 143/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0369
# Epoch 00143: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0369 - lr: 5.0000e-04
# Epoch 144/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0364
# Epoch 00144: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0364 - lr: 5.0000e-04
# Epoch 145/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0365
# Epoch 00145: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0366 - lr: 5.0000e-04
# Epoch 146/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0370
# Epoch 00146: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0370 - lr: 5.0000e-04
# Epoch 147/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0370
# Epoch 00147: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0370 - lr: 5.0000e-04
# Epoch 148/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0366
# Epoch 00148: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0366 - lr: 5.0000e-04
# Epoch 149/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0364
# Epoch 00149: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0364 - lr: 5.0000e-04
# Epoch 150/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0364
# Epoch 00150: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0364 - lr: 5.0000e-04
# Epoch 151/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0362
# Epoch 00151: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0362 - lr: 5.0000e-04
# Epoch 152/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0362
# Epoch 00152: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0362 - lr: 5.0000e-04
# Epoch 153/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0360
# Epoch 00153: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0360 - lr: 5.0000e-04
# Epoch 154/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0363
# Epoch 00154: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0363 - lr: 5.0000e-04
# Epoch 155/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0363
# Epoch 00155: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0364 - lr: 5.0000e-04
# Epoch 156/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0362
# Epoch 00156: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0362 - lr: 5.0000e-04
# Epoch 157/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0359
# Epoch 00157: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 158/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0357
# Epoch 00158: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0357 - lr: 5.0000e-04
# Epoch 159/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0360
# Epoch 00159: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0360 - lr: 5.0000e-04
# Epoch 160/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0360
# Epoch 00160: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0360 - lr: 5.0000e-04
# Epoch 161/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0360
# Epoch 00161: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0360 - lr: 5.0000e-04
# Epoch 162/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0361
# Epoch 00162: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0361 - lr: 5.0000e-04
# Epoch 163/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0358
# Epoch 00163: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0358 - lr: 5.0000e-04
# Epoch 164/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0360
# Epoch 00164: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 165/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0358
# Epoch 00165: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0358 - lr: 5.0000e-04
# Epoch 166/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0357
# Epoch 00166: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0357 - lr: 5.0000e-04
# Epoch 167/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0359
# Epoch 00167: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 168/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0357
# Epoch 00168: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0357 - lr: 5.0000e-04
# Epoch 169/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0360
# Epoch 00169: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0360 - lr: 5.0000e-04
# Epoch 170/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0359
# Epoch 00170: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 171/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0358
# Epoch 00171: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0358 - lr: 5.0000e-04
# Epoch 172/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0358
# Epoch 00172: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0358 - lr: 5.0000e-04
# Epoch 173/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0355
# Epoch 00173: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0355 - lr: 5.0000e-04
# Epoch 174/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0356
# Epoch 00174: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0357 - lr: 5.0000e-04
# Epoch 175/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0359
# Epoch 00175: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 176/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0361
# Epoch 00176: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0361 - lr: 5.0000e-04
# Epoch 177/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0355
# Epoch 00177: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0356 - lr: 5.0000e-04
# Epoch 178/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0354
# Epoch 00178: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 46ms/step - loss: 0.0354 - lr: 5.0000e-04
# Epoch 179/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0355
# Epoch 00179: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 47ms/step - loss: 0.0355 - lr: 5.0000e-04
# Epoch 180/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0356
# Epoch 00180: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 46ms/step - loss: 0.0356 - lr: 5.0000e-04
# Epoch 181/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0354
# Epoch 00181: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0354 - lr: 5.0000e-04
# Epoch 182/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0355
# Epoch 00182: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 46ms/step - loss: 0.0356 - lr: 5.0000e-04
# Epoch 183/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0354
# Epoch 00183: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0355 - lr: 5.0000e-04
# Epoch 184/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0353
# Epoch 00184: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 46ms/step - loss: 0.0353 - lr: 5.0000e-04
# Epoch 185/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0351
# Epoch 00185: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0351 - lr: 5.0000e-04
# Epoch 186/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0354
# Epoch 00186: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0354 - lr: 5.0000e-04
# Epoch 187/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0354
# Epoch 00187: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0354 - lr: 5.0000e-04
# Epoch 188/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0351
# Epoch 00188: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0351 - lr: 5.0000e-04
# Epoch 189/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0354
# Epoch 00189: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0355 - lr: 5.0000e-04
# Epoch 190/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0359
# Epoch 00190: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 191/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0355
# Epoch 00191: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0355 - lr: 5.0000e-04
# Epoch 192/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0354
# Epoch 00192: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0354 - lr: 5.0000e-04
# Epoch 193/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0351
# Epoch 00193: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 46ms/step - loss: 0.0351 - lr: 5.0000e-04
# Epoch 194/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 00194: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0349 - lr: 5.0000e-04
# Epoch 195/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0350
# Epoch 00195: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0350 - lr: 5.0000e-04
# Epoch 196/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0350
# Epoch 00196: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0350 - lr: 5.0000e-04
# Epoch 197/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0350
# Epoch 00197: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0350 - lr: 5.0000e-04
# Epoch 198/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 00198: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 46ms/step - loss: 0.0349 - lr: 5.0000e-04
# Epoch 199/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0348
# Epoch 00199: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0348 - lr: 5.0000e-04
# Epoch 200/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0347
# Epoch 00200: saving model to run/vae/0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0348 - lr: 5.0000e-04

# %%
import pickle
import os
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.datasets import mnist, cifar100,cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, save_img, img_to_array

import pandas as pd

import numpy as np
from os import walk, getcwd
import h5py

import scipy
from glob import glob

from tensorflow.keras.applications import vgg19
from tensorflow.keras import backend as K

import pdb


class ImageLabelLoader():
    def __init__(self, image_folder, target_size):
        self.image_folder = image_folder
        self.target_size = target_size

    def build(self, att, batch_size, label = None):

        data_gen = ImageDataGenerator(rescale=1./255)
        if label:
            data_flow = data_gen.flow_from_dataframe(
                att
                , self.image_folder
                , x_col='image_id'
                , y_col=label
                , target_size=self.target_size 
                , class_mode='other'
                , batch_size=batch_size
                , shuffle=True
            )
        else:
            data_flow = data_gen.flow_from_dataframe(
                att
                , self.image_folder
                , x_col='image_id'
                , target_size=self.target_size 
                , class_mode='input'
                , batch_size=batch_size
                , shuffle=True
            )

        return data_flow




class DataLoader():
    def __init__(self, dataset_name, img_res=(256, 256)):
        self.dataset_name = dataset_name
        self.img_res = img_res

    def load_data(self, domain, batch_size=1, is_testing=False):
        data_type = "train%s" % domain if not is_testing else "test%s" % domain
        path = glob('./data/%s/%s/*' % (self.dataset_name, data_type))

        batch_images = np.random.choice(path, size=batch_size)

        imgs = []
        for img_path in batch_images:
            img = self.imread(img_path)
            if not is_testing:
                img = scipy.misc.imresize(img, self.img_res)

                if np.random.random() > 0.5:
                    img = np.fliplr(img)
            else:
                img = scipy.misc.imresize(img, self.img_res)
            imgs.append(img)

        imgs = np.array(imgs)/127.5 - 1.

        return imgs

    def load_batch(self, batch_size=1, is_testing=False):
        data_type = "train" if not is_testing else "val"
        path_A = glob('./data/%s/%sA/*' % (self.dataset_name, data_type))
        path_B = glob('./data/%s/%sB/*' % (self.dataset_name, data_type))

        self.n_batches = int(min(len(path_A), len(path_B)) / batch_size)
        total_samples = self.n_batches * batch_size

        # Sample n_batches * batch_size from each path list so that model sees all
        # samples from both domains
        path_A = np.random.choice(path_A, total_samples, replace=False)
        path_B = np.random.choice(path_B, total_samples, replace=False)

        for i in range(self.n_batches-1):
            batch_A = path_A[i*batch_size:(i+1)*batch_size]
            batch_B = path_B[i*batch_size:(i+1)*batch_size]
            imgs_A, imgs_B = [], []
            for img_A, img_B in zip(batch_A, batch_B):
                img_A = self.imread(img_A)
                img_B = self.imread(img_B)

                img_A = scipy.misc.imresize(img_A, self.img_res)
                img_B = scipy.misc.imresize(img_B, self.img_res)

                if not is_testing and np.random.random() > 0.5:
                        img_A = np.fliplr(img_A)
                        img_B = np.fliplr(img_B)

                imgs_A.append(img_A)
                imgs_B.append(img_B)

            imgs_A = np.array(imgs_A)/127.5 - 1.
            imgs_B = np.array(imgs_B)/127.5 - 1.

            yield imgs_A, imgs_B

    def load_img(self, path):
        img = self.imread(path)
        img = scipy.misc.imresize(img, self.img_res)
        img = img/127.5 - 1.
        return img[np.newaxis, :, :, :]

    def imread(self, path):
        return scipy.misc.imread(path, mode='RGB').astype(np.float)




def load_model(model_class, folder):
    
    with open(os.path.join(folder, 'params.pkl'), 'rb') as f:
        params = pickle.load(f)

    model = model_class(*params)

    model.load_weights(os.path.join(folder, 'weights/weights.h5'))

    return model


def load_mnist():
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    x_train = x_train.astype('float32') / 255.
    x_train = x_train.reshape(x_train.shape + (1,))
    x_test = x_test.astype('float32') / 255.
    x_test = x_test.reshape(x_test.shape + (1,))

    return (x_train, y_train), (x_test, y_test)

def load_mnist_gan():
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    x_train = (x_train.astype('float32') - 127.5) / 127.5
    x_train = x_train.reshape(x_train.shape + (1,))
    x_test = (x_test.astype('float32') - 127.5) / 127.5
    x_test = x_test.reshape(x_test.shape + (1,))

    return (x_train, y_train), (x_test, y_test)



def load_fashion_mnist(input_rows, input_cols, path='./data/fashion/fashion-mnist_train.csv'):
    #read the csv data
    df = pd.read_csv(path)
    #extract the image pixels
    X_train = df.drop(columns = ['label'])
    X_train = X_train.values
    X_train = (X_train.astype('float32') - 127.5) / 127.5
    X_train = X_train.reshape(X_train.shape[0], input_rows, input_cols, 1)
    #extract the labels
    y_train = df['label'].values
    
    return X_train, y_train

def load_safari(folder):

    mypath = os.path.join("./data", folder)
    txt_name_list = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        for f in filenames:
            if f != '.DS_Store':
                txt_name_list.append(f)
                break

    slice_train = int(80000/len(txt_name_list))  ###Setting value to be 80000 for the final dataset
    i = 0
    seed = np.random.randint(1, 10e6)

    for txt_name in txt_name_list:
        txt_path = os.path.join(mypath,txt_name)
        x = np.load(txt_path)
        x = (x.astype('float32') - 127.5) / 127.5
        # x = x.astype('float32') / 255.0
        
        x = x.reshape(x.shape[0], 28, 28, 1)
        
        y = [i] * len(x)  
        np.random.seed(seed)
        np.random.shuffle(x)
        np.random.seed(seed)
        np.random.shuffle(y)
        x = x[:slice_train]
        y = y[:slice_train]
        if i != 0: 
            xtotal = np.concatenate((x,xtotal), axis=0)
            ytotal = np.concatenate((y,ytotal), axis=0)
        else:
            xtotal = x
            ytotal = y
        i += 1
        
    return xtotal, ytotal



def load_cifar(label, num):
    if num == 10:
        (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    else:
        (x_train, y_train), (x_test, y_test) = cifar100.load_data(label_mode = 'fine')

    train_mask = [y[0]==label for y in y_train]
    test_mask = [y[0]==label for y in y_test]

    x_data = np.concatenate([x_train[train_mask], x_test[test_mask]])
    y_data = np.concatenate([y_train[train_mask], y_test[test_mask]])

    x_data = (x_data.astype('float32') - 127.5) / 127.5
 
    return (x_data, y_data)


def load_celeb(data_name, image_size, batch_size):
    data_folder = os.path.join("./data", data_name)

    data_gen = ImageDataGenerator(preprocessing_function=lambda x: (x.astype('float32') - 127.5) / 127.5)

    x_train = data_gen.flow_from_directory(data_folder
                                            , target_size = (image_size,image_size)
                                            , batch_size = batch_size
                                            , shuffle = True
                                            , class_mode = 'input'
                                            , subset = "training"
                                                )

    return x_train


def load_music(data_name, filename, n_bars, n_steps_per_bar):
    file = os.path.join("./data", data_name, filename)

    with np.load(file, encoding='bytes') as f:
        data = f['train']

    data_ints = []

    for x in data:
        counter = 0
        cont = True
        while cont:
            if not np.any(np.isnan(x[counter:(counter+4)])):
                cont = False
            else:
                counter += 4

        if n_bars * n_steps_per_bar < x.shape[0]:
            data_ints.append(x[counter:(counter + (n_bars * n_steps_per_bar)),:])


    data_ints = np.array(data_ints)

    n_songs = data_ints.shape[0]
    n_tracks = data_ints.shape[2]

    data_ints = data_ints.reshape([n_songs, n_bars, n_steps_per_bar, n_tracks])

    max_note = 83

    where_are_NaNs = np.isnan(data_ints)
    data_ints[where_are_NaNs] = max_note + 1
    max_note = max_note + 1

    data_ints = data_ints.astype(int)

    num_classes = max_note + 1

    
    data_binary = np.eye(num_classes)[data_ints]
    data_binary[data_binary==0] = -1
    data_binary = np.delete(data_binary, max_note,-1)

    data_binary = data_binary.transpose([0,1,2, 4,3])
    
    

    

    return data_binary, data_ints, data


def preprocess_image(data_name, file, img_nrows, img_ncols):

    image_path = os.path.join('./data', data_name, file)

    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
#AutoEncoder analysis
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.stats import norm

# %%
# run params
SECTION = 'vae'
RUN_ID = '0001'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %%
AE = load_model(Autoencoder, RUN_FOLDER)

# %%
n_to_show = 10
example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]

z_points = AE.encoder.predict(example_images)

reconst_images = AE.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    ax = fig.add_subplot(2, n_to_show, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=ax.transAxes)   
    ax.imshow(img, cmap='gray_r')

for i in range(n_to_show):
    img = reconst_images[i].squeeze()
    ax = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    ax.axis('off')
    ax.imshow(img, cmap='gray_r')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4527: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "

# %%
n_to_show = 5000
grid_size =15
figsize = 12

example_idx = np.random.choice(range(len(x_test)),n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = AE.encoder.predict(example_images)

min_x = min(z_points[:,0])
max_x =max(z_points[:,0])
min_y = min(z_points[:,1])
max_y = max(z_points[:,1])

plt.figure(figsize = (figsize, figsize))
plt.scatter(z_points[:,0], z_points[:,1], c ='black', alpha=0.5, s=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4527: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "

# %%
z_points[0]
# Out:
# array([0.2664347, 2.0673509], dtype=float32)

# %%
figsize = 5

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)

grid_size = 10
grid_depth = 3
figsize = 15

x = np.random.uniform(min_x,max_x, size = grid_size * grid_depth)
y = np.random.uniform(min_y,max_y, size = grid_size * grid_depth)
z_grid = np.array(list(zip(x, y)))
reconst = AE.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()

fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=10, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4527: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "

# %%
n_to_show = 5000
grid_size = 15
figsize = 20

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = AE.encoder.predict(example_images)

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4527: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "

# %%
n_to_show = 5000
grid_size = 20
figsize = 8

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = AE.encoder.predict(example_images)

plt.figure(figsize=(5, 5))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()

# x = norm.ppf(np.linspace(0.05, 0.95, 10))
# y = norm.ppf(np.linspace(0.05, 0.95, 10))
x = np.linspace(min(z_points[:, 0]), max(z_points[:, 0]), grid_size)
y = np.linspace(max(z_points[:, 1]), min(z_points[:, 1]), grid_size)
xv, yv = np.meshgrid(x, y)
xv = xv.flatten()
yv = yv.flatten()
z_grid = np.array(list(zip(xv, yv)))

reconst = AE.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'black'#, cmap='rainbow' , c= example_labels
            , alpha=1, s=5)




plt.show()


fig = plt.figure(figsize=(figsize, figsize))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(grid_size**2):
    ax = fig.add_subplot(grid_size, grid_size, i+1)
    ax.axis('off')
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4527: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
